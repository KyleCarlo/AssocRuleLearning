# %% [markdown]
# ## Association Rule Learning Homework
#
# *Prepared by:*
# **Jude Michael Teves**
# Faculty, Software Technology Department
# College of Computer Studies - De La Salle University

# %% [markdown]
# ---
#
# Submitted by:
# - Guerra, Jose Maria Angelo
# - Hinolan, Charles Joseph
# - Lasala, Kyle Carlo
# - Lorenzo, Antonio Jose Maria
# - Roco, Katrina Bianca

# %% [markdown]
# ## Requirements
#
# Answer the following questions:
#
# **Groceries Dataset**
# 1. Calculate the association rules and find the `significant/interesting` items in this dataset. Feel free to use any threshold value. (10 pts)
#     - group the items by member
#     - group the items by month
# 2. What would you recommend to the owner of a grocery store given these association rules? (15 pts)
# 3. Is there any other grouping that could give us high confidence/interest? (10 pts)
#
# **Another Dataset**
# 1. Find another dataset that can be turned into an association rule learning problem. Ideally, more than 1000 transactions/records. This does not have to be grocery-related. (20 pts)
# 2. Similar to the grocery dataset, calculate the association rules and find the `significant/interesting` items. (10 pts)
# 3. What would you recommend given the association rules? (25 pts)
# 4. Any other learning?
#
# Note:
#  - You have to create a writeup on the code you've written. Make sure that the code is clean as well. (5 pts)
#  - Cite references if there are any. If you will be using the code I've given, cite it. If you got help from your peers, cite it as well. (5 pts)
#  - Submit the link for your copy of this Google Colaboratory notebook. **Make sure it's public**. You may use incognito to see if the link is accessible.
#
# <hr>
#
# ## Grading Criteria
#
# |Criteria|Points|
# |---|---|
# |Groceries Dataset Analysis|35|
# |Another Dataset Analysis|55|
# |Code Cleanliness|5|
# |References|5|

# %% [markdown]
# # __Groceries Dataset__

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# ### Import libraries
#
# We will be using the `PyFIM` library to do association rule learning in this homework. If this is not already installed in your environment, you may use the either of the following commands in your command line:
#
# ```conda install -c conda-forge pyfim``` or
# ```pip install pyfim```

# %%
import pandas as pd
import matplotlib.pyplot as plt
from fim import arules, apriori, fpgrowth

# %% [markdown]
# ### Prepare the dataset
#
# We will be utilizing the <a href="https://www.kaggle.com/datasets/heeraldedhia/groceries-dataset">Groceries dataset</a> from Kaggle.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Cyntwikip/data-repository/main/groceries.csv')
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
# checking datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB

# %%
# convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  datetime64[ns]
#  2   itemDescription  38765 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 908.7+ KB

# %%
# checking items
unique_items = df['itemDescription'].unique()
print("Number of Unique Items:", len(unique_items))
print(sorted(unique_items))
# Out:
# Number of Unique Items: 167
# ['Instant food products', 'UHT-milk', 'abrasive cleaner', 'artif. sweetener', 'baby cosmetics', 'bags', 'baking powder', 'bathroom cleaner', 'beef', 'berries', 'beverages', 'bottled beer', 'bottled water', 'brandy', 'brown bread', 'butter', 'butter milk', 'cake bar', 'candles', 'candy', 'canned beer', 'canned fish', 'canned fruit', 'canned vegetables', 'cat food', 'cereals', 'chewing gum', 'chicken', 'chocolate', 'chocolate marshmallow', 'citrus fruit', 'cleaner', 'cling film/bags', 'cocoa drinks', 'coffee', 'condensed milk', 'cooking chocolate', 'cookware', 'cream', 'cream cheese ', 'curd', 'curd cheese', 'decalcifier', 'dental care', 'dessert', 'detergent', 'dish cleaner', 'dishes', 'dog food', 'domestic eggs', 'female sanitary products', 'finished products', 'fish', 'flour', 'flower (seeds)', 'flower soil/fertilizer', 'frankfurter', 'frozen chicken', 'frozen dessert', 'frozen fish', 'frozen fruits', 'frozen meals', 'frozen potato products', 'frozen vegetables', 'fruit/vegetable juice', 'grapes', 'hair spray', 'ham', 'hamburger meat', 'hard cheese', 'herbs', 'honey', 'house keeping products', 'hygiene articles', 'ice cream', 'instant coffee', 'jam', 'ketchup', 'kitchen towels', 'kitchen utensil', 'light bulbs', 'liqueur', 'liquor', 'liquor (appetizer)', 'liver loaf', 'long life bakery product', 'make up remover', 'male cosmetics', 'margarine', 'mayonnaise', 'meat', 'meat spreads', 'misc. beverages', 'mustard', 'napkins', 'newspapers', 'nut snack', 'nuts/prunes', 'oil', 'onions', 'organic products', 'organic sausage', 'other vegetables', 'packaged fruit/vegetables', 'pasta', 'pastry', 'pet care', 'photo/film', 'pickled vegetables', 'pip fruit', 'popcorn', 'pork', 'pot plants', 'potato products', 'preservation products', 'processed cheese', 'prosecco', 'pudding powder', 'ready soups', 'red/blush wine', 'rice', 'roll products ', 'rolls/buns', 'root vegetables', 'rubbing alcohol', 'rum', 'salad dressing', 'salt', 'salty snack', 'sauces', 'sausage', 'seasonal products', 'semi-finished bread', 'shopping bags', 'skin care', 'sliced cheese', 'snack products', 'soap', 'soda', 'soft cheese', 'softener', 'soups', 'sparkling wine', 'specialty bar', 'specialty cheese', 'specialty chocolate', 'specialty fat', 'specialty vegetables', 'spices', 'spread cheese', 'sugar', 'sweet spreads', 'syrup', 'tea', 'tidbits', 'toilet cleaner', 'tropical fruit', 'turkey', 'vinegar', 'waffles', 'whipped/sour cream', 'whisky', 'white bread', 'white wine', 'whole milk', 'yogurt', 'zwieback']

# %% [markdown]
# Grouped the items by `Member_number` and `Date`

# %%
df_grouped = df.groupby(['Member_number','Date']).agg(list)
df_grouped.sort_values(['Member_number', 'Date'], inplace=True)
df_grouped
# Out:
#                                                             itemDescription
# Member_number Date
# 1000          2014-06-24                  [whole milk, pastry, salty snack]
#               2015-03-15  [sausage, whole milk, semi-finished bread, yog...
#               2015-05-27                         [soda, pickled vegetables]
#               2015-07-24                     [canned beer, misc. beverages]
#               2015-11-25                        [sausage, hygiene articles]
# ...                                                                     ...
# 4999          2015-05-16                  [butter milk, whipped/sour cream]
#               2015-12-26                             [bottled water, herbs]
# 5000          2014-03-09                    [fruit/vegetable juice, onions]
#               2014-11-16                   [bottled beer, other vegetables]
#               2015-02-10       [soda, root vegetables, semi-finished bread]
#
# [14963 rows x 1 columns]

# %%
# convert to list format
transactions = df_grouped['itemDescription'].to_list()
transactions
# Out:
# [['whole milk', 'pastry', 'salty snack'],
#  ['sausage', 'whole milk', 'semi-finished bread', 'yogurt'],
#  ['soda', 'pickled vegetables'],
#  ['canned beer', 'misc. beverages'],
#  ['sausage', 'hygiene articles'],
#  ['sausage', 'whole milk', 'rolls/buns'],
#  ['whole milk', 'soda'],
#  ['frankfurter', 'soda', 'whipped/sour cream'],
#  ['beef', 'white bread'],
#  ['frankfurter', 'curd'],
#  ['frozen vegetables', 'other vegetables'],
#  ['butter', 'whole milk'],
#  ['tropical fruit', 'sugar'],
#  ['butter milk', 'specialty chocolate'],
#  ['frozen meals', 'dental care'],
#  ['rolls/buns', 'rolls/buns'],
#  ['root vegetables', 'detergent'],
#  ['sausage', 'rolls/buns'],
#  ['pip fruit', 'whole milk', 'tropical fruit'],
#  ['dish cleaner', 'cling film/bags'],
#  ['rolls/buns', 'red/blush wine', 'chocolate'],
#  ['canned beer', 'frozen fish'],
#  ['other vegetables', 'shopping bags'],
#  ['root vegetables', 'whole milk', 'pastry'],
#  ['whole milk', 'chocolate', 'packaged fruit/vegetables', 'rolls/buns'],
#  ['other vegetables', 'hygiene articles'],
#  ['rolls/buns', 'rolls/buns'],
#  ['whipped/sour cream', 'margarine'],
#  ['whole milk', 'rice'],
#  ['bottled water', 'softener', 'rolls/buns'],
#  ['shopping bags', 'skin care'],
#  ['whole milk',
#   'frankfurter',
#   'chicken',
#   'frankfurter',
#   'flour',
#   'chocolate',
#   'bottled beer',
#   'rolls/buns'],
#  ['tropical fruit',
#   'soda',
#   'yogurt',
#   'root vegetables',
#   'yogurt',
#   'domestic eggs',
#   'white wine',
#   'photo/film'],
#  ['hamburger meat', 'liquor (appetizer)', 'liver loaf', 'dessert'],
#  ['canned fish', 'cocoa drinks'],
#  ['tropical fruit', 'yogurt'],
#  ['pastry', 'ketchup'],
#  ['herbs', 'yogurt', 'newspapers'],
#  ['pip fruit', 'coffee', 'UHT-milk'],
#  ['kitchen towels', 'sliced cheese'],
#  ['bottled water', 'specialty bar'],
#  ['frankfurter', 'bottled water'],
#  ['pip fruit', 'candles', 'rolls/buns'],
#  ['citrus fruit', 'candy', 'bottled water', 'rolls/buns'],
#  ['curd cheese', 'pastry'],
#  ['whole milk',
#   'frankfurter',
#   'candles',
#   'grapes',
#   'herbs',
#   'other vegetables',
#   'yogurt'],
#  ['frozen vegetables', 'brown bread'],
#  ['processed cheese', 'whole milk'],
#  ['frankfurter', 'yogurt'],
#  ['tropical fruit',
#   'root vegetables',
#   'rolls/buns',
#   'onions',
#   'shopping bags'],
#  ['hard cheese', 'napkins', 'bottled water'],
#  ['whole milk', 'candy'],
#  ['tropical fruit', 'frozen vegetables'],
#  ['mustard', 'whipped/sour cream'],
#  ['other vegetables', 'mustard'],
#  ['root vegetables', 'mayonnaise'],
#  ['frozen meals', 'whole milk'],
#  ['white bread', 'meat', 'domestic eggs', 'roll products '],
#  ['hamburger meat', 'butter milk'],
#  ['whole milk', 'rolls/buns'],
#  ['canned beer', 'cookware'],
#  ['whole milk', 'sausage', 'bottled beer', 'yogurt'],
#  ['fruit/vegetable juice', 'rolls/buns', 'chocolate'],
#  ['salty snack', 'beef'],
#  ['citrus fruit', 'whole milk'],
#  ['soft cheese', 'pip fruit'],
#  ['chicken', 'red/blush wine'],
#  ['rolls/buns', 'frankfurter', 'oil', 'pip fruit', 'mayonnaise'],
#  ['UHT-milk', 'bottled beer'],
#  ['other vegetables', 'root vegetables'],
#  ['yogurt', 'beef'],
#  ['brown bread', 'pet care'],
#  ['other vegetables', 'rolls/buns'],
#  ['soda', 'dessert', 'shopping bags'],
#  ['beverages', 'domestic eggs'],
#  ['berries', 'cake bar'],
#  ['curd', 'long life bakery product'],
#  ['butter milk', 'root vegetables'],
#  ['hamburger meat', 'red/blush wine'],
#  ['frozen meals', 'butter', 'newspapers', 'yogurt'],
#  ['canned beer', 'shopping bags'],
#  ['canned beer', 'spices', 'rolls/buns', 'frozen fish'],
#  ['sliced cheese', 'butter'],
#  ['liquor', 'curd', 'yogurt', 'tropical fruit'],
#  ['rolls/buns', 'baking powder'],
#  ['beef', 'napkins'],
#  ['whole milk', 'whipped/sour cream'],
#  ['sausage', 'fruit/vegetable juice'],
#  ['chicken', 'frozen meals'],
#  ['male cosmetics', 'curd'],
#  ['domestic eggs', 'soda'],
#  ['sausage', 'whipped/sour cream', 'specialty bar'],
#  ['whipped/sour cream',
#   'root vegetables',
#   'rolls/buns',
#   'packaged fruit/vegetables'],
#  ['white bread', 'bottled beer', 'yogurt', 'berries'],
#  ['fish', 'root vegetables', 'tropical fruit', 'other vegetables'],
#  ['coffee', 'shopping bags'],
#  ['ham', 'cream cheese '],
#  ['canned beer', 'UHT-milk'],
#  ['sausage', 'dessert', 'rolls/buns', 'pickled vegetables'],
#  ['root vegetables', 'long life bakery product'],
#  ['citrus fruit', 'yogurt'],
#  ['fruit/vegetable juice', 'salty snack', 'candy', 'dental care', 'butter'],
#  ['root vegetables', 'whipped/sour cream', 'root vegetables', 'canned beer'],
#  ['softener', 'salt', 'whole milk'],
#  ['rolls/buns', 'bottled water'],
#  ['rolls/buns', 'red/blush wine'],
#  ['pork', 'hamburger meat'],
#  ['rolls/buns', 'sugar'],
#  ['rolls/buns', 'baking powder', 'onions', 'bottled water'],
#  ['soda', 'butter'],
#  ['onions', 'canned beer', 'flower (seeds)'],
#  ['specialty chocolate', 'root vegetables'],
#  ['dessert', 'ham'],
#  ['ice cream', 'pot plants'],
#  ['beverages', 'cream cheese '],
#  ['other vegetables', 'other vegetables', 'berries'],
#  ['whipped/sour cream', 'newspapers'],
#  ['white bread', 'whole milk', 'pastry', 'shopping bags'],
#  ['berries',
#   'soda',
#   'butter',
#   'other vegetables',
#   'white bread',
#   'cream cheese '],
#  ['ice cream', 'whipped/sour cream'],
#  ['yogurt', 'root vegetables'],
#  ['frankfurter', 'pastry'],
#  ['fruit/vegetable juice', 'dessert'],
#  ['sausage', 'snack products', 'rolls/buns'],
#  ['tropical fruit', 'soda', 'rolls/buns'],
#  ['chicken', 'waffles'],
#  ['pip fruit', 'cling film/bags', 'yogurt', 'cat food'],
#  ['bottled water', 'domestic eggs', 'frozen meals'],
#  ['tropical fruit', 'newspapers'],
#  ['whole milk', 'frozen vegetables'],
#  ['pip fruit', 'white wine', 'white bread', 'salt'],
#  ['whole milk', 'yogurt', 'yogurt', 'rolls/buns'],
#  ['sausage', 'frozen vegetables'],
#  ['whole milk', 'newspapers'],
#  ['fruit/vegetable juice', 'vinegar'],
#  ['tropical fruit', 'white bread', 'rolls/buns'],
#  ['citrus fruit', 'shopping bags', 'chewing gum', 'cake bar'],
#  ['frankfurter', 'yogurt', 'canned beer'],
#  ['margarine', 'napkins'],
#  ['sausage', 'pork', 'butter', 'whole milk', 'fruit/vegetable juice'],
#  ['whole milk', 'pip fruit', 'whipped/sour cream'],
#  ['other vegetables', 'specialty chocolate'],
#  ['pip fruit', 'herbs', 'frozen meals'],
#  ['Instant food products', 'whipped/sour cream', 'butter', 'cake bar'],
#  ['salty snack', 'rolls/buns'],
#  ['yogurt', 'rolls/buns'],
#  ['whole milk', 'pasta', 'rolls/buns'],
#  ['root vegetables', 'white bread'],
#  ['tropical fruit', 'chicken', 'onions', 'packaged fruit/vegetables'],
#  ['chicken', 'frozen vegetables', 'candy'],
#  ['tropical fruit', 'brown bread', 'whole milk'],
#  ['prosecco', 'dessert'],
#  ['hamburger meat', 'yogurt'],
#  ['beef', 'dessert'],
#  ['citrus fruit', 'bottled water'],
#  ['whole milk', 'other vegetables'],
#  ['tropical fruit', 'sliced cheese'],
#  ['napkins', 'whole milk', 'chocolate marshmallow'],
#  ['citrus fruit', 'rolls/buns', 'whole milk'],
#  ['tropical fruit', 'other vegetables'],
#  ['root vegetables', 'curd'],
#  ['root vegetables', 'yogurt', 'butter', 'yogurt'],
#  ['fruit/vegetable juice', 'specialty chocolate', 'Instant food products'],
#  ['chicken', 'onions'],
#  ['whole milk', 'pastry'],
#  ['pork', 'bottled water'],
#  ['pip fruit', 'soda'],
#  ['curd', 'soda'],
#  ['sweet spreads', 'butter'],
#  ['rolls/buns', 'condensed milk', 'whole milk', 'soda'],
#  ['rolls/buns', 'tropical fruit'],
#  ['specialty bar', 'margarine'],
#  ['butter', 'whole milk'],
#  ['white bread', 'candy'],
#  ['frankfurter', 'herbs'],
#  ['waffles', 'beverages'],
#  ['house keeping products', 'yogurt'],
#  ['pasta', 'yogurt', 'cat food'],
#  ['whipped/sour cream', 'hygiene articles'],
#  ['UHT-milk', 'other vegetables', 'dishes'],
#  ['meat', 'whole milk'],
#  ['hamburger meat', 'bottled beer'],
#  ['pork', 'coffee', 'frozen vegetables'],
#  ['shopping bags', 'shopping bags'],
#  ['other vegetables', 'soda', 'rolls/buns', 'dishes'],
#  ['tropical fruit',
#   'other vegetables',
#   'hamburger meat',
#   'popcorn',
#   'female sanitary products'],
#  ['fish', 'tropical fruit', 'red/blush wine', 'cream cheese '],
#  ['beef', 'shopping bags'],
#  ['root vegetables', 'grapes'],
#  ['chicken', 'beverages', 'coffee'],
#  ['butter', 'dog food'],
#  ['soda', 'whole milk'],
#  ['bottled water', 'chewing gum'],
#  ['soda', 'hamburger meat'],
#  ['frankfurter', 'whipped/sour cream'],
#  ['butter milk', 'yogurt', 'yogurt', 'margarine'],
#  ['pork',
#   'other vegetables',
#   'yogurt',
#   'shopping bags',
#   'soft cheese',
#   'detergent'],
#  ['soda', 'soda'],
#  ['waffles', 'rolls/buns'],
#  ['whole milk', 'sugar'],
#  ['chicken', 'frozen vegetables'],
#  ['other vegetables', 'whole milk'],
#  ['hamburger meat', 'pastry'],
#  ['soda', 'fruit/vegetable juice'],
#  ['bottled beer', 'oil'],
#  ['frankfurter', 'citrus fruit', 'margarine'],
#  ['photo/film', 'other vegetables'],
#  ['pork', 'white wine'],
#  ['bottled water', 'yogurt', 'newspapers', 'soda'],
#  ['ham', 'whole milk'],
#  ['pip fruit', 'other vegetables'],
#  ['whipped/sour cream', 'meat spreads'],
#  ['soda', 'domestic eggs', 'sliced cheese', 'soda'],
#  ['salty snack', 'pickled vegetables'],
#  ['tropical fruit', 'UHT-milk'],
#  ['chicken', 'other vegetables'],
#  ['yogurt', 'root vegetables'],
#  ['sausage', 'bottled water'],
#  ['root vegetables', 'other vegetables'],
#  ['dessert', 'spread cheese'],
#  ['sausage', 'salty snack', 'cling film/bags'],
#  ['soda', 'fruit/vegetable juice', 'bottled beer'],
#  ['beef', 'chocolate'],
#  ['whipped/sour cream', 'hard cheese'],
#  ['beverages', 'dessert'],
#  ['whole milk',
#   'tropical fruit',
#   'root vegetables',
#   'Instant food products',
#   'margarine'],
#  ['whole milk', 'sauces'],
#  ['white bread', 'frozen fruits'],
#  ['ham', 'whipped/sour cream', 'ketchup'],
#  ['tropical fruit',
#   'whole milk',
#   'other vegetables',
#   'long life bakery product'],
#  ['other vegetables', 'yogurt', 'whole milk', 'butter', 'shopping bags'],
#  ['whole milk', 'citrus fruit'],
#  ['rolls/buns', 'candy'],
#  ['cream cheese ', 'rolls/buns'],
#  ['root vegetables', 'whole milk'],
#  ['long life bakery product', 'root vegetables', 'other vegetables'],
#  ['tropical fruit', 'whole milk', 'long life bakery product', 'rum'],
#  ['hamburger meat', 'soda'],
#  ['tropical fruit', 'rolls/buns'],
#  ['red/blush wine', 'frozen fish'],
#  ['beef', 'dessert'],
#  ['frankfurter', 'tropical fruit'],
#  ['root vegetables', 'bottled beer'],
#  ['whole milk', 'other vegetables'],
#  ['oil', 'shopping bags'],
#  ['whole milk', 'tropical fruit'],
#  ['hamburger meat', 'pork'],
#  ['rolls/buns', 'tropical fruit', 'coffee', 'chocolate'],
#  ['soda', 'yogurt'],
#  ['pork', 'spread cheese'],
#  ['pork', 'rolls/buns'],
#  ['brown bread', 'fruit/vegetable juice'],
#  ['salt', 'domestic eggs'],
#  ['bottled beer', 'tropical fruit', 'sliced cheese', 'dishes'],
#  ['citrus fruit', 'red/blush wine'],
#  ['cream cheese ', 'newspapers'],
#  ['yogurt', 'roll products ', 'fruit/vegetable juice'],
#  ['ham', 'other vegetables'],
#  ['frankfurter', 'canned beer'],
#  ['brown bread', 'salt'],
#  ['yogurt', 'bottled water', 'domestic eggs'],
#  ['pip fruit', 'curd', 'pip fruit', 'prosecco'],
#  ['finished products', 'brown bread', 'dishes'],
#  ['detergent', 'candy'],
#  ['semi-finished bread', 'ketchup'],
#  ['oil', 'shopping bags'],
#  ['misc. beverages', 'instant coffee'],
#  ['fruit/vegetable juice', 'flower (seeds)'],
#  ['UHT-milk', 'canned fish'],
#  ['pip fruit', 'rolls/buns'],
#  ['frankfurter', 'frozen meals', 'dishes'],
#  ['frankfurter', 'citrus fruit', 'bottled water', 'fruit/vegetable juice'],
#  ['sausage', 'brown bread'],
#  ['frankfurter', 'chicken', 'butter', 'bottled water'],
#  ['sausage', 'butter', 'bottled water'],
#  ['ham', 'whole milk', 'whole milk', 'coffee'],
#  ['pastry', 'pasta'],
#  ['canned beer', 'rolls/buns', 'artif. sweetener', 'soda'],
#  ['white bread', 'brown bread'],
#  ['other vegetables', 'butter'],
#  ['rolls/buns', 'root vegetables'],
#  ['tropical fruit', 'soda'],
#  ['chicken', 'soda'],
#  ['frankfurter', 'curd', 'white bread', 'rolls/buns', 'coffee'],
#  ['red/blush wine', 'bottled water', 'sweet spreads'],
#  ['rolls/buns', 'onions', 'napkins'],
#  ['canned beer', 'soda'],
#  ['root vegetables', 'frozen vegetables', 'pet care'],
#  ['beverages', 'yogurt'],
#  ['tropical fruit', 'whole milk'],
#  ['other vegetables', 'frankfurter', 'newspapers', 'whole milk', 'pastry'],
#  ['coffee', 'butter milk'],
#  ['specialty bar',
#   'tropical fruit',
#   'yogurt',
#   'bottled beer',
#   'baking powder'],
#  ['bottled water', 'hygiene articles'],
#  ['beef', 'margarine', 'other vegetables'],
#  ['specialty chocolate', 'soda', 'bathroom cleaner'],
#  ['hamburger meat', 'whole milk'],
#  ['pork', 'sliced cheese'],
#  ['pip fruit', 'other vegetables'],
#  ['other vegetables', 'shopping bags', 'soda'],
#  ['yogurt', 'newspapers'],
#  ['root vegetables', 'citrus fruit'],
#  ['rolls/buns', 'soda'],
#  ['canned beer', 'herbs', 'margarine'],
#  ['ice cream', 'whipped/sour cream'],
#  ['other vegetables', 'beef', 'soda', 'curd', 'butter'],
#  ['rolls/buns', 'citrus fruit'],
#  ['sausage', 'beverages'],
#  ['whole milk', 'whole milk'],
#  ['specialty chocolate', 'white bread'],
#  ['other vegetables', 'whole milk'],
#  ['ham', 'white bread'],
#  ['coffee', 'berries'],
#  ['soda', 'flower (seeds)', 'jam'],
#  ['sausage', 'pip fruit', 'chocolate'],
#  ['herbs', 'pot plants', 'cake bar'],
#  ['yogurt', 'berries'],
#  ['whole milk', 'hard cheese'],
#  ['tropical fruit',
#   'meat',
#   'other vegetables',
#   'domestic eggs',
#   'baking powder'],
#  ['yogurt', 'sauces'],
#  ['sausage',
#   'whisky',
#   'specialty chocolate',
#   'dishes',
#   'yogurt',
#   'napkins',
#   'detergent',
#   'pastry'],
#  ['beef', 'yogurt'],
#  ['ice cream', 'whole milk'],
#  ['yogurt', 'newspapers'],
#  ['root vegetables',
#   'soda',
#   'specialty bar',
#   'other vegetables',
#   'frozen vegetables'],
#  ['photo/film', 'shopping bags'],
#  ['rolls/buns',
#   'grapes',
#   'bottled beer',
#   'sausage',
#   'salty snack',
#   'Instant food products',
#   'domestic eggs',
#   'bottled water'],
#  ['frankfurter', 'other vegetables', 'bottled beer'],
#  ['dessert', 'domestic eggs'],
#  ['whole milk', 'brown bread'],
#  ['pasta', 'whole milk', 'waffles'],
#  ['newspapers', 'salty snack'],
#  ['chocolate marshmallow', 'other vegetables'],
#  ['hamburger meat', 'detergent', 'flour'],
#  ['sausage', 'tropical fruit', 'misc. beverages', 'root vegetables'],
#  ['tropical fruit', 'soda'],
#  ['sausage', 'whole milk'],
#  ['yogurt', 'shopping bags'],
#  ['pickled vegetables', 'flour'],
#  ['packaged fruit/vegetables', 'bottled water', 'pork', 'domestic eggs'],
#  ['pip fruit', 'fruit/vegetable juice'],
#  ['sausage', 'whole milk', 'cake bar'],
#  ['shopping bags', 'root vegetables'],
#  ['whipped/sour cream', 'curd', 'shopping bags'],
#  ['hard cheese', 'whole milk'],
#  ['frankfurter', 'whipped/sour cream', 'bottled water'],
#  ['tropical fruit', 'whole milk', 'soda', 'curd'],
#  ['citrus fruit', 'dessert'],
#  ['tropical fruit', 'candy'],
#  ['rolls/buns', 'shopping bags', 'cat food'],
#  ['canned beer', 'napkins', 'rolls/buns'],
#  ['tropical fruit',
#   'citrus fruit',
#   'yogurt',
#   'frankfurter',
#   'specialty chocolate',
#   'hard cheese',
#   'whole milk',
#   'canned beer'],
#  ['root vegetables', 'frozen vegetables', 'bottled water', 'cat food'],
#  ['grapes', 'other vegetables'],
#  ['pip fruit', 'brown bread'],
#  ['root vegetables', 'instant coffee'],
#  ['spread cheese', 'pork'],
#  ['hamburger meat', 'pasta'],
#  ['whole milk', 'yogurt'],
#  ['soda',
#   'hygiene articles',
#   'grapes',
#   'pudding powder',
#   'butter milk',
#   'butter'],
#  ['whole milk', 'processed cheese'],
#  ['brown bread', 'sparkling wine'],
#  ['rolls/buns', 'other vegetables', 'whipped/sour cream'],
#  ['root vegetables', 'frozen vegetables'],
#  ['candy', 'white wine'],
#  ['yogurt', 'beverages', 'brown bread'],
#  ['other vegetables', 'white bread', 'detergent'],
#  ['chicken', 'pastry', 'candles'],
#  ['ice cream', 'herbs'],
#  ['waffles', 'hygiene articles', 'tea'],
#  ['cream', 'yogurt'],
#  ['yogurt', 'root vegetables'],
#  ['yogurt', 'other vegetables', 'rolls/buns', 'herbs'],
#  ['domestic eggs', 'yogurt'],
#  ['pork', 'whole milk'],
#  ['other vegetables', 'white bread'],
#  ['bottled water', 'yogurt', 'tropical fruit', 'whole milk'],
#  ['beef', 'specialty fat', 'newspapers'],
#  ['onions', 'newspapers'],
#  ['rolls/buns', 'semi-finished bread'],
#  ['whole milk', 'pastry'],
#  ['shopping bags', 'rolls/buns'],
#  ['liver loaf', 'chicken', 'rolls/buns', 'spread cheese', 'shopping bags'],
#  ['citrus fruit', 'misc. beverages'],
#  ['citrus fruit', 'misc. beverages'],
#  ['pastry', 'canned beer', 'whipped/sour cream', 'grapes'],
#  ['frozen potato products', 'specialty cheese'],
#  ['salty snack', 'pastry', 'oil'],
#  ['brown bread', 'whole milk', 'shopping bags'],
#  ['chocolate', 'whole milk'],
#  ['curd', 'sugar'],
#  ['pip fruit', 'margarine'],
#  ['pip fruit', 'salty snack', 'pastry'],
#  ['citrus fruit', 'frozen vegetables', 'margarine'],
#  ['margarine', 'yogurt'],
#  ['pickled vegetables', 'liquor'],
#  ['bottled water', 'chocolate'],
#  ['soda', 'salty snack'],
#  ['ham', 'yogurt'],
#  ['pastry', 'baking powder', 'butter', 'margarine', 'curd', 'dishes'],
#  ['whole milk', 'soda'],
#  ['whole milk', 'frozen vegetables', 'soda', 'UHT-milk'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['bottled water', 'flour', 'sugar'],
#  ['beef', 'semi-finished bread'],
#  ['dish cleaner', 'ice cream', 'jam', 'newspapers'],
#  ['whole milk', 'yogurt', 'newspapers'],
#  ['curd', 'canned beer'],
#  ['pork', 'pudding powder', 'domestic eggs'],
#  ['bottled beer', 'specialty bar', 'baking powder'],
#  ['chocolate', 'brown bread', 'salty snack'],
#  ['root vegetables', 'shopping bags'],
#  ['root vegetables', 'citrus fruit'],
#  ['dog food', 'sausage', 'dessert', 'shopping bags'],
#  ['chicken', 'shopping bags'],
#  ['misc. beverages', 'UHT-milk', 'white bread'],
#  ['turkey', 'root vegetables'],
#  ['other vegetables', 'butter'],
#  ['whipped/sour cream', 'yogurt'],
#  ['other vegetables', 'yogurt'],
#  ['other vegetables', 'napkins'],
#  ['brown bread', 'butter milk', 'canned vegetables', 'soda'],
#  ['other vegetables', 'zwieback'],
#  ['brown bread', 'soda'],
#  ['other vegetables',
#   'cream cheese ',
#   'liquor',
#   'root vegetables',
#   'newspapers',
#   'hard cheese'],
#  ['chicken', 'bottled water'],
#  ['newspapers', 'white bread', 'rolls/buns', 'beverages'],
#  ['frankfurter', 'rolls/buns'],
#  ['meat', 'whole milk', 'whipped/sour cream'],
#  ['bottled beer', 'frozen vegetables', 'sliced cheese'],
#  ['pip fruit', 'processed cheese', 'canned beer'],
#  ['berries', 'condensed milk'],
#  ['house keeping products', 'rolls/buns', 'pickled vegetables', 'curd'],
#  ['ham', 'yogurt'],
#  ['whole milk', 'hair spray', 'butter', 'pastry'],
#  ['grapes', 'whole milk'],
#  ['tropical fruit', 'sugar'],
#  ['soda', 'UHT-milk', 'newspapers', 'white bread'],
#  ['meat', 'other vegetables'],
#  ['other vegetables', 'specialty bar'],
#  ['citrus fruit', 'brown bread'],
#  ['pastry',
#   'condensed milk',
#   'rice',
#   'tropical fruit',
#   'chocolate marshmallow'],
#  ['coffee', 'shopping bags'],
#  ['chicken', 'dishes'],
#  ['root vegetables', 'frozen vegetables'],
#  ['bottled water', 'citrus fruit'],
#  ['rolls/buns', 'oil', 'yogurt'],
#  ['pip fruit', 'whole milk'],
#  ['frozen vegetables', 'rolls/buns', 'cling film/bags'],
#  ['pork', 'soda', 'canned vegetables'],
#  ['bottled beer', 'hygiene articles'],
#  ['yogurt', 'soda'],
#  ['root vegetables', 'margarine', 'rolls/buns'],
#  ['rolls/buns', 'margarine'],
#  ['condensed milk', 'shopping bags'],
#  ['sausage', 'pastry'],
#  ['popcorn', 'citrus fruit'],
#  ['rolls/buns', 'whipped/sour cream'],
#  ['misc. beverages', 'whole milk', 'long life bakery product'],
#  ['newspapers', 'pork', 'root vegetables', 'napkins'],
#  ['soda', 'roll products '],
#  ['citrus fruit', 'soda'],
#  ['frankfurter', 'rolls/buns', 'shopping bags', 'margarine'],
#  ['other vegetables', 'butter', 'pastry', 'UHT-milk'],
#  ['specialty bar', 'soda', 'frozen vegetables', 'frozen vegetables'],
#  ['liquor', 'domestic eggs'],
#  ['frankfurter', 'white bread'],
#  ['meat', 'coffee'],
#  ['whole milk', 'baking powder'],
#  ['flower (seeds)', 'white wine'],
#  ['grapes', 'frozen meals', 'flower (seeds)'],
#  ['tea', 'yogurt', 'shopping bags', 'brown bread'],
#  ['cream cheese ', 'specialty chocolate'],
#  ['yogurt', 'softener'],
#  ['margarine', 'soda'],
#  ['tropical fruit', 'cream cheese ', 'cream cheese '],
#  ['bottled water', 'frankfurter', 'dessert', 'root vegetables'],
#  ['bottled beer', 'whole milk'],
#  ['other vegetables',
#   'semi-finished bread',
#   'other vegetables',
#   'rolls/buns',
#   'shopping bags',
#   'salty snack'],
#  ['soda', 'whole milk'],
#  ['coffee', 'shopping bags', 'shopping bags'],
#  ['yogurt', 'pastry'],
#  ['sausage', 'rolls/buns', 'rice'],
#  ['pork', 'whole milk', 'napkins'],
#  ['curd', 'domestic eggs'],
#  ['cream cheese ', 'newspapers'],
#  ['pastry', 'brown bread', 'yogurt'],
#  ['other vegetables', 'oil'],
#  ['hard cheese', 'butter'],
#  ['whole milk', 'other vegetables'],
#  ['sausage', 'shopping bags', 'soda', 'butter', 'dessert', 'soda'],
#  ['citrus fruit', 'flower (seeds)'],
#  ['instant coffee', 'shopping bags'],
#  ['rolls/buns', 'fruit/vegetable juice'],
#  ['root vegetables', 'butter milk'],
#  ['tropical fruit', 'other vegetables'],
#  ['tropical fruit', 'butter milk', 'brown bread'],
#  ['herbs', 'citrus fruit'],
#  ['other vegetables', 'beef'],
#  ['tropical fruit', 'whole milk'],
#  ['nut snack', 'canned beer'],
#  ['whole milk', 'other vegetables', 'other vegetables', 'sugar'],
#  ['citrus fruit', 'napkins'],
#  ['rolls/buns', 'butter milk'],
#  ['whole milk', 'root vegetables'],
#  ['tropical fruit', 'soft cheese'],
#  ['rolls/buns', 'brown bread', 'canned beer'],
#  ['pork', 'pickled vegetables'],
#  ['tropical fruit', 'misc. beverages'],
#  ['photo/film', 'frankfurter', 'other vegetables', 'curd', 'waffles'],
#  ['pip fruit', 'other vegetables', 'cling film/bags'],
#  ['tropical fruit', 'yogurt'],
#  ['cat food', 'rolls/buns'],
#  ['rolls/buns', 'whole milk', 'soda'],
#  ['berries', 'white bread'],
#  ['newspapers', 'soups'],
#  ['other vegetables', 'napkins'],
#  ['rolls/buns', 'soda'],
#  ['chicken', 'brown bread'],
#  ['UHT-milk', 'soda'],
#  ['pork', 'soda'],
#  ['oil', 'pickled vegetables'],
#  ['misc. beverages', 'spread cheese'],
#  ['soda', 'whole milk', 'whole milk', 'sugar'],
#  ['root vegetables', 'coffee'],
#  ['pork', 'domestic eggs'],
#  ['chicken', 'domestic eggs', 'white bread'],
#  ['soda', 'whipped/sour cream'],
#  ['meat', 'whole milk'],
#  ['canned beer', 'fish'],
#  ['hard cheese', 'root vegetables', 'white bread'],
#  ['brown bread', 'other vegetables'],
#  ['bottled beer', 'soda'],
#  ['tropical fruit', 'root vegetables'],
#  ['curd', 'soft cheese'],
#  ['frozen vegetables', 'pip fruit', 'root vegetables', 'cereals'],
#  ['other vegetables', 'berries', 'candy', 'sliced cheese'],
#  ['yogurt', 'soda', 'yogurt'],
#  ['bottled water', 'shopping bags', 'waffles'],
#  ['whole milk', 'bottled beer'],
#  ['pork', 'margarine'],
#  ['frozen meals', 'detergent'],
#  ['soda', 'whole milk'],
#  ['specialty chocolate', 'canned fish'],
#  ['root vegetables', 'soda', 'long life bakery product'],
#  ['soda', 'other vegetables'],
#  ['pork', 'yogurt'],
#  ['yogurt',
#   'sausage',
#   'whole milk',
#   'shopping bags',
#   'white bread',
#   'dog food',
#   'baking powder',
#   'sliced cheese'],
#  ['pork', 'tropical fruit'],
#  ['soda', 'other vegetables'],
#  ['soda', 'bottled beer', 'chicken', 'yogurt'],
#  ['seasonal products', 'frozen vegetables', 'yogurt'],
#  ['pip fruit', 'berries'],
#  ['long life bakery product', 'rolls/buns', 'UHT-milk', 'bottled water'],
#  ['canned beer', 'sugar'],
#  ['other vegetables', 'fruit/vegetable juice'],
#  ['curd', 'soft cheese'],
#  ['berries', 'pip fruit', 'pastry'],
#  ['curd cheese', 'soda'],
#  ['whole milk', 'rolls/buns'],
#  ['soda', 'frozen meals'],
#  ['pork', 'domestic eggs'],
#  ['tropical fruit', 'rolls/buns', 'canned beer', 'dish cleaner'],
#  ['chewing gum', 'whole milk', 'bottled beer', 'ready soups'],
#  ['chicken', 'cake bar'],
#  ['butter', 'ice cream'],
#  ['frankfurter', 'soft cheese', 'mustard'],
#  ['whole milk', 'grapes'],
#  ['female sanitary products', 'rolls/buns'],
#  ['root vegetables', 'other vegetables', 'frozen vegetables'],
#  ['citrus fruit', 'sausage', 'whole milk', 'canned beer'],
#  ['whole milk', 'sausage', 'pet care', 'yogurt'],
#  ['whole milk', 'house keeping products'],
#  ['frankfurter', 'brandy'],
#  ['berries', 'other vegetables'],
#  ['beef', 'curd', 'frozen meals'],
#  ['tropical fruit', 'UHT-milk', 'napkins', 'whole milk'],
#  ['whole milk', 'bottled water'],
#  ['yogurt', 'citrus fruit'],
#  ['whole milk', 'cream cheese '],
#  ['rolls/buns', 'other vegetables', 'butter', 'root vegetables', 'rolls/buns'],
#  ['citrus fruit', 'light bulbs'],
#  ['frozen vegetables', 'domestic eggs'],
#  ['citrus fruit', 'soda'],
#  ['yogurt', 'whole milk'],
#  ['whole milk', 'root vegetables'],
#  ['shopping bags', 'frozen meals'],
#  ['domestic eggs', 'beef', 'coffee', 'bottled beer'],
#  ['butter', 'chewing gum'],
#  ['pip fruit', 'tropical fruit', 'mustard'],
#  ['beef', 'newspapers', 'bottled beer'],
#  ['other vegetables', 'yogurt', 'whole milk', 'spread cheese'],
#  ['white bread', 'yogurt'],
#  ['canned beer', 'berries', 'male cosmetics', 'fruit/vegetable juice'],
#  ['misc. beverages', 'coffee'],
#  ['red/blush wine', 'salty snack'],
#  ['canned beer', 'citrus fruit'],
#  ['sausage', 'bottled water'],
#  ['white bread', 'frozen vegetables'],
#  ['whole milk', 'beef', 'citrus fruit', 'newspapers', 'bottled water'],
#  ['other vegetables', 'sliced cheese'],
#  ['whole milk', 'root vegetables', 'canned vegetables'],
#  ['beef', 'house keeping products'],
#  ['frozen vegetables', 'whole milk'],
#  ['pork', 'packaged fruit/vegetables', 'chocolate'],
#  ['curd', 'spices'],
#  ['root vegetables', 'brown bread'],
#  ['bottled water', 'tropical fruit'],
#  ['rolls/buns', 'other vegetables'],
#  ['coffee', 'domestic eggs'],
#  ['sweet spreads', 'herbs', 'long life bakery product'],
#  ['bottled beer', 'whole milk', 'UHT-milk', 'chocolate'],
#  ['frankfurter', 'frozen vegetables'],
#  ['liquor', 'bottled water'],
#  ['other vegetables', 'rolls/buns'],
#  ['waffles', 'whole milk', 'other vegetables', 'white bread'],
#  ['napkins', 'napkins'],
#  ['soda', 'margarine'],
#  ['finished products', 'newspapers', 'whipped/sour cream'],
#  ['napkins', 'cleaner'],
#  ['soda', 'detergent'],
#  ['cake bar', 'bottled beer'],
#  ['whole milk', 'canned beer'],
#  ['chocolate', 'shopping bags'],
#  ['pip fruit', 'whipped/sour cream'],
#  ['whole milk', 'sparkling wine'],
#  ['citrus fruit', 'whipped/sour cream'],
#  ['whole milk',
#   'turkey',
#   'pork',
#   'dog food',
#   'rolls/buns',
#   'soda',
#   'bottled water',
#   'bottled water'],
#  ['chicken', 'pip fruit'],
#  ['soda', 'whipped/sour cream'],
#  ['other vegetables', 'soda'],
#  ['brown bread', 'pasta'],
#  ['specialty chocolate', 'beverages'],
#  ['bottled water', 'onions'],
#  ['rolls/buns', 'margarine'],
#  ['specialty bar', 'newspapers'],
#  ['bottled beer', 'fruit/vegetable juice', 'rolls/buns'],
#  ['hard cheese', 'rolls/buns'],
#  ['citrus fruit', 'syrup'],
#  ['baking powder', 'pickled vegetables'],
#  ['root vegetables', 'cling film/bags'],
#  ['pip fruit', 'whipped/sour cream'],
#  ['rolls/buns', 'soft cheese', 'fruit/vegetable juice'],
#  ['hamburger meat', 'other vegetables'],
#  ['citrus fruit', 'brown bread', 'specialty chocolate'],
#  ['pasta', 'oil'],
#  ['whole milk',
#   'citrus fruit',
#   'shopping bags',
#   'white wine',
#   'soda',
#   'yogurt'],
#  ['bottled water', 'yogurt', 'beef', 'berries', 'chocolate', 'butter'],
#  ['tropical fruit', 'other vegetables'],
#  ['hard cheese', 'sugar', 'bottled water'],
#  ['soda', 'whole milk'],
#  ['frozen potato products', 'domestic eggs', 'curd cheese'],
#  ['whole milk', 'tropical fruit'],
#  ['pastry', 'other vegetables'],
#  ['rolls/buns', 'canned beer', 'brown bread', 'dessert'],
#  ['tropical fruit', 'shopping bags'],
#  ['oil', 'coffee'],
#  ['other vegetables', 'ice cream', 'pork', 'salt'],
#  ['bottled water', 'chocolate', 'jam'],
#  ['cereals', 'soda'],
#  ['chicken', 'frozen meals', 'napkins'],
#  ['frozen potato products', 'whole milk'],
#  ['citrus fruit', 'white bread'],
#  ['bottled beer', 'oil', 'whole milk', 'dishes'],
#  ['white bread', 'mayonnaise'],
#  ['sausage', 'root vegetables'],
#  ['butter', 'mustard'],
#  ['rolls/buns', 'red/blush wine'],
#  ['candy', 'baking powder', 'canned fish'],
#  ['beef', 'butter milk'],
#  ['ice cream', 'hamburger meat', 'shopping bags', 'whole milk', 'soft cheese'],
#  ['hamburger meat', 'pip fruit'],
#  ['sausage', 'domestic eggs'],
#  ['sausage',
#   'bottled beer',
#   'dessert',
#   'butter',
#   'cream cheese ',
#   'other vegetables',
#   'canned beer',
#   'brown bread'],
#  ['root vegetables',
#   'ham',
#   'butter',
#   'brown bread',
#   'pastry',
#   'spread cheese'],
#  ['beef', 'whole milk', 'newspapers'],
#  ['root vegetables', 'sweet spreads'],
#  ['beef', 'whole milk', 'frozen meals'],
#  ['frankfurter', 'canned beer'],
#  ['ice cream', 'chewing gum'],
#  ['pip fruit', 'specialty bar', 'chocolate'],
#  ['soda', 'butter'],
#  ['white bread', 'domestic eggs'],
#  ['soda', 'detergent'],
#  ['other vegetables', 'whole milk', 'canned fruit'],
#  ['soda', 'soda'],
#  ['citrus fruit', 'domestic eggs'],
#  ['other vegetables', 'onions', 'shopping bags'],
#  ['butter milk', 'cleaner', 'bottled water'],
#  ['other vegetables', 'bottled beer'],
#  ['whole milk', 'rolls/buns', 'soda'],
#  ['tropical fruit', 'dessert'],
#  ['bottled beer', 'sliced cheese'],
#  ['hamburger meat', 'bottled beer'],
#  ['pip fruit', 'rolls/buns', 'soda'],
#  ['bottled water', 'soda'],
#  ['whipped/sour cream', 'specialty chocolate'],
#  ['canned beer', 'root vegetables'],
#  ['other vegetables', 'meat spreads'],
#  ['root vegetables', 'root vegetables'],
#  ['sparkling wine', 'waffles'],
#  ['berries', 'white bread'],
#  ['hamburger meat', 'citrus fruit', 'specialty chocolate', 'other vegetables'],
#  ['brown bread', 'pastry'],
#  ['butter', 'seasonal products', 'fruit/vegetable juice'],
#  ['soda', 'shopping bags'],
#  ['citrus fruit', 'root vegetables'],
#  ['whole milk', 'bottled water', 'honey'],
#  ['pip fruit', 'napkins'],
#  ['butter', 'coffee', 'soda', 'pastry'],
#  ['butter', 'shopping bags'],
#  ['whole milk', 'soft cheese'],
#  ['finished products', 'liquor'],
#  ['pip fruit', 'shopping bags'],
#  ['domestic eggs', 'newspapers'],
#  ['mayonnaise', 'candy', 'rolls/buns', 'bottled beer'],
#  ['pip fruit', 'waffles'],
#  ['whole milk', 'brown bread'],
#  ['beef', 'whipped/sour cream'],
#  ['sausage', 'chocolate'],
#  ['citrus fruit', 'yogurt'],
#  ['root vegetables',
#   'citrus fruit',
#   'root vegetables',
#   'misc. beverages',
#   'sliced cheese',
#   'packaged fruit/vegetables',
#   'yogurt',
#   'whipped/sour cream'],
#  ['citrus fruit', 'napkins'],
#  ['frozen fish', 'specialty chocolate'],
#  ['other vegetables', 'specialty chocolate', 'newspapers'],
#  ['grapes', 'rolls/buns'],
#  ['beverages', 'sausage'],
#  ['rolls/buns', 'whole milk', 'white bread', 'popcorn'],
#  ['sugar', 'canned vegetables', 'flour', 'bottled water', 'salty snack'],
#  ['brown bread', 'detergent'],
#  ['citrus fruit', 'root vegetables'],
#  ['candy', 'dessert', 'rolls/buns', 'canned fish'],
#  ['candles', 'whole milk'],
#  ['misc. beverages', 'coffee'],
#  ['coffee', 'oil'],
#  ['yogurt', 'roll products '],
#  ['yogurt', 'rolls/buns'],
#  ['soda', 'curd cheese', 'root vegetables', 'semi-finished bread'],
#  ['softener', 'chocolate'],
#  ['soda', 'beverages'],
#  ['root vegetables', 'yogurt'],
#  ['whole milk', 'waffles'],
#  ['rolls/buns', 'pastry'],
#  ['grapes', 'chicken', 'bottled beer', 'root vegetables'],
#  ['sliced cheese', 'pip fruit'],
#  ['whole milk', 'oil'],
#  ['white bread', 'bottled water', 'ready soups', 'curd'],
#  ['yogurt', 'whole milk', 'yogurt', 'chewing gum'],
#  ['tropical fruit', 'hygiene articles', 'candles'],
#  ['sausage', 'cat food'],
#  ['pastry',
#   'sausage',
#   'soda',
#   'rolls/buns',
#   'sugar',
#   'soda',
#   'other vegetables',
#   'whole milk',
#   'softener'],
#  ['ham', 'pickled vegetables', 'shopping bags'],
#  ['whole milk', 'yogurt', 'semi-finished bread'],
#  ['frankfurter', 'whole milk'],
#  ['soft cheese', 'bottled water'],
#  ['pork', 'beef', 'yogurt'],
#  ['rolls/buns', 'frozen meals'],
#  ['shopping bags', 'misc. beverages'],
#  ['tropical fruit', 'butter milk'],
#  ['yogurt', 'shopping bags'],
#  ['ham', 'brown bread'],
#  ['sausage', 'dessert'],
#  ['fruit/vegetable juice', 'long life bakery product', 'specialty cheese'],
#  ['butter', 'margarine'],
#  ['finished products', 'domestic eggs'],
#  ['specialty bar', 'whole milk'],
#  ['frankfurter', 'butter', 'specialty bar', 'yogurt'],
#  ['UHT-milk', 'other vegetables'],
#  ['rolls/buns', 'tropical fruit', 'salty snack', 'specialty bar'],
#  ['beef', 'domestic eggs'],
#  ['tropical fruit', 'salt'],
#  ['tropical fruit', 'cat food'],
#  ['root vegetables', 'other vegetables'],
#  ['domestic eggs', 'fruit/vegetable juice'],
#  ['chicken',
#   'beef',
#   'pork',
#   'beef',
#   'newspapers',
#   'dessert',
#   'margarine',
#   'brown bread',
#   'newspapers'],
#  ['citrus fruit', 'bottled beer'],
#  ['syrup', 'waffles'],
#  ['meat', 'chicken', 'yogurt', 'pip fruit'],
#  ['sauces', 'yogurt'],
#  ['grapes', 'root vegetables', 'shopping bags'],
#  ['pip fruit', 'other vegetables', 'semi-finished bread', 'sliced cheese'],
#  ['citrus fruit', 'long life bakery product'],
#  ['turkey', 'onions'],
#  ['canned beer', 'brown bread'],
#  ['whole milk',
#   'soda',
#   'root vegetables',
#   'pastry',
#   'specialty fat',
#   'bottled water',
#   'napkins',
#   'tropical fruit'],
#  ['whole milk', 'sugar'],
#  ['citrus fruit', 'grapes', 'bottled water'],
#  ['whole milk', 'dog food', 'pastry'],
#  ['citrus fruit', 'citrus fruit'],
#  ['meat', 'cling film/bags', 'curd'],
#  ['pork', 'frozen meals'],
#  ['other vegetables', 'fruit/vegetable juice'],
#  ['whole milk', 'sausage', 'yogurt', 'whole milk', 'butter'],
#  ['tropical fruit', 'rolls/buns', 'frozen fish'],
#  ['tropical fruit', 'meat', 'whole milk', 'candles'],
#  ['red/blush wine', 'instant coffee'],
#  ['canned beer', 'brown bread'],
#  ['sausage', 'pasta'],
#  ['canned beer', 'margarine', 'chocolate'],
#  ['rolls/buns',
#   'specialty chocolate',
#   'napkins',
#   'onions',
#   'rice',
#   'rolls/buns',
#   'butter milk',
#   'dental care'],
#  ['pastry', 'waffles'],
#  ['frankfurter', 'ice cream'],
#  ['sugar', 'bottled water'],
#  ['canned beer', 'coffee'],
#  ['condensed milk', 'onions'],
#  ['citrus fruit', 'butter', 'UHT-milk'],
#  ['packaged fruit/vegetables', 'flour'],
#  ['citrus fruit', 'semi-finished bread', 'yogurt'],
#  ['ham', 'rum'],
#  ['UHT-milk', 'cooking chocolate'],
#  ['sausage', 'specialty chocolate'],
#  ['whole milk', 'curd'],
#  ['pastry', 'rolls/buns'],
#  ['white bread', 'jam'],
#  ['butter milk', 'soda', 'seasonal products'],
#  ['shopping bags',
#   'whole milk',
#   'whole milk',
#   'whole milk',
#   'detergent',
#   'flour'],
#  ['dessert', 'sliced cheese', 'bottled beer', 'other vegetables'],
#  ['photo/film', 'brown bread'],
#  ['hard cheese', 'pastry'],
#  ['beef',
#   'citrus fruit',
#   'specialty bar',
#   'white bread',
#   'soda',
#   'vinegar',
#   'long life bakery product',
#   'domestic eggs'],
#  ['yogurt', 'whipped/sour cream'],
#  ['photo/film', 'beverages', 'bottled beer'],
#  ['mustard', 'brown bread'],
#  ['beef', 'white bread', 'frozen potato products'],
#  ['ham', 'whipped/sour cream', 'newspapers'],
#  ['canned beer', 'sliced cheese'],
#  ['soda', 'canned beer'],
#  ['soda', 'butter milk', 'soda'],
#  ['whole milk', 'other vegetables'],
#  ['ham', 'domestic eggs'],
#  ['frankfurter', 'pastry', 'misc. beverages'],
#  ['yogurt', 'margarine'],
#  ['hard cheese', 'soda'],
#  ['ice cream', 'onions'],
#  ['white wine', 'photo/film', 'whipped/sour cream'],
#  ['grapes', 'detergent'],
#  ['sausage', 'root vegetables'],
#  ['pork', 'sliced cheese', 'flour'],
#  ['pasta', 'canned beer'],
#  ['rolls/buns', 'bottled beer'],
#  ['butter', 'grapes', 'bottled water'],
#  ['UHT-milk', 'curd'],
#  ['whipped/sour cream', 'shopping bags'],
#  ['other vegetables', 'rolls/buns'],
#  ['rolls/buns',
#   'whipped/sour cream',
#   'waffles',
#   'rolls/buns',
#   'margarine',
#   'soda',
#   'salty snack',
#   'soda',
#   'canned beer'],
#  ['chicken', 'whole milk'],
#  ['butter milk', 'other vegetables'],
#  ['root vegetables', 'margarine', 'bottled water'],
#  ['yogurt', 'shopping bags', 'coffee'],
#  ['curd', 'pastry'],
#  ['salty snack', 'root vegetables'],
#  ['butter', 'roll products '],
#  ['canned beer', 'bottled beer'],
#  ['other vegetables', 'curd', 'abrasive cleaner'],
#  ['condensed milk', 'other vegetables'],
#  ['bottled water', 'soda'],
#  ['dog food', 'processed cheese'],
#  ['sausage', 'sausage', 'bottled beer', 'spread cheese'],
#  ['shopping bags', 'waffles'],
#  ['newspapers', 'pip fruit', 'dishes'],
#  ['whole milk', 'cling film/bags'],
#  ['butter milk', 'hard cheese'],
#  ['cleaner', 'misc. beverages'],
#  ['citrus fruit', 'other vegetables'],
#  ['pork', 'other vegetables', 'cream cheese '],
#  ['beverages', 'sugar'],
#  ['rolls/buns', 'hard cheese'],
#  ['ham',
#   'whole milk',
#   'other vegetables',
#   'soda',
#   'white bread',
#   'tropical fruit',
#   'sugar'],
#  ['frankfurter', 'margarine'],
#  ['meat', 'soda'],
#  ['roll products ', 'waffles'],
#  ['condensed milk', 'whole milk'],
#  ['sausage', 'processed cheese'],
#  ['whipped/sour cream', 'yogurt'],
#  ['finished products', 'yogurt', 'bottled beer', 'bottled water'],
#  ['brown bread', 'tropical fruit'],
#  ['onions', 'hard cheese'],
#  ['soda', 'shopping bags'],
#  ['frozen vegetables',
#   'sausage',
#   'whole milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'other vegetables',
#   'oil',
#   'frozen fish',
#   'baking powder'],
#  ['oil', 'margarine'],
#  ['whole milk', 'specialty cheese'],
#  ['specialty chocolate', 'pasta', 'soda', 'long life bakery product'],
#  ['meat', 'other vegetables', 'pasta'],
#  ['butter', 'chocolate'],
#  ['citrus fruit', 'other vegetables'],
#  ['sausage', 'frozen meals'],
#  ['sausage', 'dog food', 'bottled beer', 'bottled water'],
#  ['beverages', 'beverages', 'sugar', 'pasta', 'domestic eggs'],
#  ['shopping bags', 'tropical fruit'],
#  ['soda', 'cling film/bags'],
#  ['UHT-milk', 'soft cheese'],
#  ['candy', 'soda'],
#  ['rolls/buns', 'salty snack', 'bottled water', 'shopping bags'],
#  ['onions', 'soft cheese'],
#  ['coffee', 'white bread'],
#  ['dessert', 'condensed milk', 'rolls/buns', 'shopping bags'],
#  ['soda', 'soda', 'canned fruit', 'processed cheese', 'soda', 'shopping bags'],
#  ['grapes', 'other vegetables'],
#  ['tropical fruit', 'rolls/buns'],
#  ['turkey', 'shopping bags'],
#  ['whipped/sour cream', 'yogurt'],
#  ['yogurt', 'canned beer'],
#  ['tropical fruit', 'berries'],
#  ['other vegetables', 'UHT-milk'],
#  ['butter', 'candy'],
#  ['frozen vegetables', 'other vegetables'],
#  ['chicken', 'butter'],
#  ['margarine', 'margarine'],
#  ['citrus fruit', 'skin care'],
#  ['root vegetables', 'frozen vegetables'],
#  ['dessert', 'packaged fruit/vegetables'],
#  ['tropical fruit', 'pip fruit'],
#  ['beef', 'curd'],
#  ['frankfurter', 'whole milk'],
#  ['citrus fruit', 'coffee'],
#  ['soda', 'frozen meals', 'bottled beer'],
#  ['other vegetables', 'chewing gum'],
#  ['canned beer', 'dessert', 'fruit/vegetable juice'],
#  ['grapes', 'other vegetables'],
#  ['chicken', 'pastry'],
#  ['pork', 'turkey', 'pot plants', 'whole milk', 'soda', 'dishes'],
#  ['pastry', 'liqueur'],
#  ['sausage', 'processed cheese', 'baking powder', 'specialty cheese'],
#  ['ham', 'napkins'],
#  ['white wine', 'specialty bar', 'specialty chocolate'],
#  ['soda', 'red/blush wine'],
#  ['tea', 'coffee'],
#  ['sugar', 'other vegetables'],
#  ['berries', 'domestic eggs'],
#  ['sausage', 'coffee'],
#  ['UHT-milk', 'herbs', 'butter', 'oil'],
#  ['frozen dessert', 'cream cheese '],
#  ['rolls/buns', 'yogurt'],
#  ['yogurt', 'coffee'],
#  ['rolls/buns',
#   'fruit/vegetable juice',
#   'frozen vegetables',
#   'whipped/sour cream'],
#  ['whole milk', 'shopping bags'],
#  ['hamburger meat', 'coffee'],
#  ['fruit/vegetable juice', 'berries'],
#  ['ice cream', 'whole milk'],
#  ['sausage', 'grapes', 'sliced cheese', 'napkins'],
#  ['pork', 'root vegetables'],
#  ['sausage', 'curd'],
#  ['pip fruit', 'shopping bags'],
#  ['whole milk', 'domestic eggs', 'canned vegetables', 'flower (seeds)'],
#  ['rolls/buns', 'hard cheese', 'rolls/buns', 'flour'],
#  ['organic sausage', 'frozen meals', 'sugar'],
#  ['whole milk', 'onions', 'pickled vegetables'],
#  ['citrus fruit', 'other vegetables'],
#  ['frozen meals', 'bottled beer'],
#  ['tropical fruit', 'white bread', 'butter'],
#  ['sausage', 'other vegetables', 'tropical fruit', 'mayonnaise'],
#  ['specialty bar', 'tropical fruit'],
#  ['bottled water', 'pastry'],
#  ['sugar', 'curd'],
#  ['tropical fruit', 'yogurt', 'semi-finished bread', 'soda'],
#  ['other vegetables', 'whole milk', 'soda'],
#  ['UHT-milk', 'canned fish', 'root vegetables', 'waffles'],
#  ['hamburger meat', 'other vegetables', 'domestic eggs'],
#  ['cream cheese ',
#   'pip fruit',
#   'citrus fruit',
#   'chicken',
#   'other vegetables',
#   'curd',
#   'specialty chocolate',
#   'pastry'],
#  ['pork', 'yogurt'],
#  ['shopping bags', 'tropical fruit', 'red/blush wine'],
#  ['pork', 'brown bread'],
#  ['other vegetables', 'sliced cheese'],
#  ['butter', 'whole milk'],
#  ['other vegetables', 'margarine', 'brown bread'],
#  ['whole milk', 'misc. beverages'],
#  ['white wine', 'sauces'],
#  ['oil', 'canned fish'],
#  ['rolls/buns', 'seasonal products'],
#  ['tropical fruit', 'root vegetables'],
#  ['red/blush wine', 'frozen meals', 'canned fruit'],
#  ['other vegetables', 'liquor', 'whole milk', 'butter milk'],
#  ['other vegetables', 'whole milk', 'softener'],
#  ['cake bar', 'flower soil/fertilizer'],
#  ['citrus fruit', 'cereals'],
#  ['pork', 'napkins'],
#  ['specialty bar', 'cleaner'],
#  ['pork', 'pastry'],
#  ['artif. sweetener', 'whole milk'],
#  ['tidbits', 'cream cheese '],
#  ['dessert', 'rolls/buns'],
#  ['coffee', 'other vegetables', 'specialty cheese'],
#  ['frozen potato products', 'domestic eggs', 'shopping bags', 'butter milk'],
#  ['citrus fruit', 'pastry'],
#  ['ice cream', 'butter'],
#  ['rolls/buns', 'dental care'],
#  ['sausage', 'onions', 'mustard'],
#  ['salt', 'citrus fruit'],
#  ['root vegetables', 'butter', 'dessert'],
#  ['curd', 'hygiene articles'],
#  ['other vegetables', 'whole milk'],
#  ['white bread', 'specialty chocolate'],
#  ['dessert', 'house keeping products'],
#  ['hard cheese', 'yogurt'],
#  ['sausage', 'whole milk', 'rolls/buns', 'bottled beer'],
#  ['whole milk', 'cream cheese ', 'semi-finished bread'],
#  ['condensed milk', 'hard cheese'],
#  ['butter', 'brown bread'],
#  ['frankfurter', 'shopping bags'],
#  ['photo/film',
#   'whole milk',
#   'yogurt',
#   'whole milk',
#   'white bread',
#   'pot plants',
#   'dessert'],
#  ...]

# %% [markdown]
# ## Association Rule Learning

# %% [markdown]
# ### Frequent Itemset Mining

# %%
# calculates the frequent itemset using fpgrowth algorithm
def get_fim(supp, transactions):
    result = fpgrowth(transactions, supp=supp, report='as')
    colnames = ['itemset'] + ['support_absolute', 'support_relative']
    df_result = pd.DataFrame(result, columns=colnames)
    df_result = df_result.sort_values('support_absolute', ascending=False)
    return df_result

# %% [markdown]
# Checking for ideal support threshold

# %%
supports = range(1, 21)  # Test supports from 1% to 20%
num_itemsets = []

for supp in supports:
    rules = get_fim(supp*-1, transactions)
    num_itemsets.append(len(rules))

plt.plot(supports, num_itemsets, marker='o')
plt.axhline(y = len(df_grouped)*0.2, color = 'r', label = '20% of transactions')
plt.xticks([x for x in range(21)])
plt.xlabel("Support Threshold (%)")
plt.ylabel("Number of Frequent Itemsets")
plt.title("Elbow Method for Choosing Support")
plt.legend()
plt.show()

# %% [markdown]
# Zoom in the Plot

# %%
plt.plot(supports, num_itemsets, marker='o')
plt.axhline(y = len(df_grouped)*0.2, color = 'r', label = '20% of transactions')
plt.xticks([x for x in range(21)])
plt.xlabel("Support Threshold (%)")
plt.ylabel("Number of Frequent Itemsets")
plt.ylim([0,20000])
plt.title("Elbow Method for Choosing Support")
plt.legend()
plt.show()

# %% [markdown]
# Support Threshold is obtained through the **elbow method** (inspired from KMeans Clustering) to generate *enough* rules and avoid *noise*. <br/>
# Ideally we want to be approximately equal to 20% of the transactions (represented by the redline) and not very steep nor flat at the given point so that we avoid the exteremely rare and extremely common itemsets. <br/>
# ***Support Threshold is set to 4.***

# %% [markdown]
# Get the Frequent Itemsets given that Support Threshold is set to 4

# %%
get_fim(-4, transactions)
# Out:
#                                      itemset  support_absolute  \
# 0                              (whole milk,)              2363
# 2                        (other vegetables,)              1827
# 6                              (rolls/buns,)              1646
# 13                                   (soda,)              1453
# 24                                 (yogurt,)              1285
# ...                                      ...               ...
# 1635                         (meat, waffles)                 4
# 250   (shopping bags, pip fruit, rolls/buns)                 4
# 602       (butter, pastry, other vegetables)                 4
# 1280       (salty snack, yogurt, whole milk)                 4
# 3068                                 (bags,)                 4
#
#       support_relative
# 0             0.157923
# 2             0.122101
# 6             0.110005
# 13            0.097106
# 24            0.085879
# ...                ...
# 1635          0.000267
# 250           0.000267
# 602           0.000267
# 1280          0.000267
# 3068          0.000267
#
# [3069 rows x 3 columns]

# %% [markdown]
# ### Significant Itemsets

# %%
# calculates the frequent itemset using fpgrowth algorithm
def get_sig(supp, conf, transactions):

    result = arules(transactions, supp=supp, conf=conf, report='asc')
    colnames = ['consequent', 'antecedent'] + ['support_absolute', 'support_relative', 'confidence_pct']
    df_result = pd.DataFrame(result, columns=colnames)
    df_result = df_result.sort_values('support_absolute', ascending=False)
    return df_result

# %%
confidence = range(10, 81, 5)  # Test supports from 1% to 20%
num_itemsets = []

for conf in confidence:
    rules = get_sig(-4, conf, transactions)
    num_itemsets.append(len(rules))

plt.plot(confidence, num_itemsets, marker='o')
plt.xlabel("Confidence Threshold (%)")
plt.ylabel("Number of Significant Itemsets")
plt.title("Elbow Method for Choosing Confidence Threshold")
plt.show()

# %%
get_sig(-4, 30, transactions)
# Out:
#             consequent                                    antecedent  \
# 1418        whole milk                                     (brandy,)
# 230         whole milk                               (pork, sausage)
# 348         whole milk                    (beef, whipped/sour cream)
# 249   other vegetables                          (pork, citrus fruit)
# 601         whole milk                     (sugar, other vegetables)
# ...                ...                                           ...
# 562         rolls/buns                            (onions, UHT-milk)
# 561         whole milk                            (onions, UHT-milk)
# 559      bottled water                           (onions, margarine)
# 558             onions  (margarine, bottled water, other vegetables)
# 1455            yogurt                                       (bags,)
#
#       support_absolute  support_relative  confidence_pct
# 1418                13          0.000869        0.342105
# 230                  9          0.000601        0.391304
# 348                  7          0.000468        0.333333
# 249                  7          0.000468        0.350000
# 601                  7          0.000468        0.368421
# ...                ...               ...             ...
# 562                  2          0.000134        0.400000
# 561                  2          0.000134        0.400000
# 559                  2          0.000134        0.500000
# 558                  2          0.000134        0.400000
# 1455                 2          0.000134        0.500000
#
# [1456 rows x 5 columns]

# %% [markdown]
# **Groceries Dataset**
# 1. Calculate the association rules and find the `significant/interesting` items in this dataset. Feel free to use any threshold value. (10 pts)
#     - group the items by member
#     - group the items by month
# 2. What would you recommend to the owner of a grocery store given these association rules? (15 pts)
#     - The owner of the grocery store can use the association rules to determine which items are frequently bought together. In this case, we recommend that the store place the following items near each other to encourage customers to buy them together (top 3):
#         - whole milk and brandy
#         - whole milk and meat (pork/sausage)
#         - whole milk with whipped/sour cream and beef
#
# 3. Is there any other grouping that could give us high confidence/interest? (10 pts)
#     - Another grouping that could give us high confidence/interest is grouping the items by day. This will allow the store to determine which items are frequently bought together on a daily basis.

# %% [markdown]
# ## Grocery Dataset Association Rule by Day

# %%
#Create day column
df['Day'] = df['Date'].dt.day_name()
df
# Out:
#        Member_number       Date        itemDescription        Day
# 0               1808 2015-07-21         tropical fruit    Tuesday
# 1               2552 2015-01-05             whole milk     Monday
# 2               2300 2015-09-19              pip fruit   Saturday
# 3               1187 2015-12-12       other vegetables   Saturday
# 4               3037 2015-02-01             whole milk     Sunday
# ...              ...        ...                    ...        ...
# 38760           4471 2014-10-08          sliced cheese  Wednesday
# 38761           2022 2014-02-23                  candy     Sunday
# 38762           1097 2014-04-16               cake bar  Wednesday
# 38763           1510 2014-12-03  fruit/vegetable juice  Wednesday
# 38764           1521 2014-12-26               cat food     Friday
#
# [38765 rows x 4 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  datetime64[ns]
#  2   itemDescription  38765 non-null  object
#  3   Day              38765 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
df_grouped = df.groupby(['Member_number','Day']).agg(list)
df_grouped.sort_values(['Member_number', 'Day'], inplace=True)
df_grouped
# Out:
#                                                                       Date  \
# Member_number Day
# 1000          Friday            [2015-07-24 00:00:00, 2015-07-24 00:00:00]
#               Sunday     [2015-03-15 00:00:00, 2015-03-15 00:00:00, 201...
#               Tuesday    [2014-06-24 00:00:00, 2014-06-24 00:00:00, 201...
#               Wednesday  [2015-05-27 00:00:00, 2015-11-25 00:00:00, 201...
# 1001          Friday     [2014-02-07 00:00:00, 2014-12-12 00:00:00, 201...
# ...                                                                    ...
# 4999          Monday            [2014-05-19 00:00:00, 2014-05-19 00:00:00]
#               Saturday   [2015-12-26 00:00:00, 2015-05-16 00:00:00, 201...
#               Wednesday  [2015-02-18 00:00:00, 2014-04-09 00:00:00, 201...
# 5000          Sunday     [2014-11-16 00:00:00, 2014-03-09 00:00:00, 201...
#               Tuesday    [2015-02-10 00:00:00, 2015-02-10 00:00:00, 201...
#
#                                                            itemDescription
# Member_number Day
# 1000          Friday                        [canned beer, misc. beverages]
#               Sunday     [sausage, whole milk, semi-finished bread, yog...
#               Tuesday                    [whole milk, pastry, salty snack]
#               Wednesday  [soda, sausage, pickled vegetables, hygiene ar...
# 1001          Friday     [sausage, whole milk, whole milk, soda, rolls/...
# ...                                                                    ...
# 4999          Monday                         [other vegetables, detergent]
#               Saturday   [bottled water, butter milk, tropical fruit, b...
#               Wednesday  [berries, semi-finished bread, onions, newspap...
# 5000          Sunday     [bottled beer, fruit/vegetable juice, other ve...
#               Tuesday         [soda, root vegetables, semi-finished bread]
#
# [11560 rows x 2 columns]

# %%
transactions = df_grouped['itemDescription'].to_list()
transactions
# Out:
# [['canned beer', 'misc. beverages'],
#  ['sausage', 'whole milk', 'semi-finished bread', 'yogurt'],
#  ['whole milk', 'pastry', 'salty snack'],
#  ['soda', 'sausage', 'pickled vegetables', 'hygiene articles'],
#  ['sausage', 'whole milk', 'whole milk', 'soda', 'rolls/buns'],
#  ['frankfurter', 'curd'],
#  ['frankfurter', 'beef', 'soda', 'white bread', 'whipped/sour cream'],
#  ['butter', 'whole milk'],
#  ['tropical fruit',
#   'butter milk',
#   'frozen vegetables',
#   'sugar',
#   'specialty chocolate',
#   'other vegetables'],
#  ['frozen meals', 'dental care'],
#  ['rolls/buns', 'rolls/buns'],
#  ['sausage', 'rolls/buns'],
#  ['root vegetables', 'detergent'],
#  ['whole milk', 'chocolate', 'packaged fruit/vegetables', 'rolls/buns'],
#  ['other vegetables', 'shopping bags', 'dish cleaner', 'cling film/bags'],
#  ['pip fruit',
#   'root vegetables',
#   'canned beer',
#   'rolls/buns',
#   'whole milk',
#   'whole milk',
#   'frozen fish',
#   'red/blush wine',
#   'tropical fruit',
#   'chocolate',
#   'pastry'],
#  ['other vegetables', 'hygiene articles'],
#  ['whipped/sour cream', 'rolls/buns', 'margarine', 'rolls/buns'],
#  ['shopping bags', 'skin care'],
#  ['bottled water', 'softener', 'rolls/buns'],
#  ['whole milk',
#   'frankfurter',
#   'chicken',
#   'frankfurter',
#   'flour',
#   'chocolate',
#   'bottled beer',
#   'rolls/buns'],
#  ['whole milk', 'rice'],
#  ['hamburger meat', 'liquor (appetizer)', 'liver loaf', 'dessert'],
#  ['tropical fruit',
#   'soda',
#   'yogurt',
#   'root vegetables',
#   'yogurt',
#   'domestic eggs',
#   'white wine',
#   'photo/film'],
#  ['canned fish', 'cocoa drinks'],
#  ['herbs', 'yogurt', 'newspapers'],
#  ['tropical fruit', 'yogurt'],
#  ['pastry', 'ketchup'],
#  ['pip fruit', 'candles', 'rolls/buns'],
#  ['bottled water', 'specialty bar'],
#  ['kitchen towels', 'sliced cheese'],
#  ['frankfurter', 'pip fruit', 'bottled water', 'coffee', 'UHT-milk'],
#  ['curd cheese', 'pastry'],
#  ['citrus fruit', 'candy', 'bottled water', 'rolls/buns'],
#  ['whole milk',
#   'frankfurter',
#   'candles',
#   'grapes',
#   'herbs',
#   'other vegetables',
#   'yogurt'],
#  ['processed cheese', 'whole milk'],
#  ['frankfurter', 'yogurt'],
#  ['frozen vegetables', 'brown bread'],
#  ['tropical fruit',
#   'root vegetables',
#   'rolls/buns',
#   'onions',
#   'shopping bags'],
#  ['white bread',
#   'meat',
#   'mustard',
#   'hard cheese',
#   'domestic eggs',
#   'roll products ',
#   'whipped/sour cream',
#   'napkins',
#   'bottled water'],
#  ['frozen meals', 'whole milk', 'whole milk', 'candy'],
#  ['other vegetables', 'mustard'],
#  ['tropical fruit', 'root vegetables', 'frozen vegetables', 'mayonnaise'],
#  ['whole milk', 'rolls/buns'],
#  ['whole milk', 'sausage', 'bottled beer', 'yogurt'],
#  ['canned beer', 'cookware'],
#  ['hamburger meat', 'butter milk'],
#  ['citrus fruit', 'whole milk'],
#  ['fruit/vegetable juice', 'rolls/buns', 'chocolate'],
#  ['salty snack', 'beef'],
#  ['UHT-milk', 'bottled beer'],
#  ['chicken', 'red/blush wine'],
#  ['soft cheese', 'pip fruit'],
#  ['rolls/buns', 'frankfurter', 'oil', 'pip fruit', 'mayonnaise'],
#  ['other vegetables', 'root vegetables'],
#  ['other vegetables', 'rolls/buns'],
#  ['yogurt', 'beef'],
#  ['brown bread', 'pet care'],
#  ['soda', 'dessert', 'shopping bags'],
#  ['butter milk', 'root vegetables'],
#  ['berries', 'beverages', 'cake bar', 'domestic eggs'],
#  ['curd', 'long life bakery product'],
#  ['hamburger meat', 'red/blush wine'],
#  ['frozen meals', 'butter', 'newspapers', 'yogurt'],
#  ['canned beer',
#   'canned beer',
#   'spices',
#   'rolls/buns',
#   'shopping bags',
#   'frozen fish'],
#  ['sliced cheese', 'butter'],
#  ['rolls/buns', 'baking powder'],
#  ['liquor', 'curd', 'yogurt', 'tropical fruit'],
#  ['sausage', 'beef', 'fruit/vegetable juice', 'napkins'],
#  ['whole milk', 'whipped/sour cream'],
#  ['domestic eggs', 'soda'],
#  ['chicken', 'frozen meals'],
#  ['white bread', 'bottled beer', 'yogurt', 'berries'],
#  ['male cosmetics', 'curd'],
#  ['whipped/sour cream',
#   'root vegetables',
#   'sausage',
#   'rolls/buns',
#   'packaged fruit/vegetables',
#   'whipped/sour cream',
#   'specialty bar'],
#  ['fish', 'root vegetables', 'tropical fruit', 'other vegetables'],
#  ['ham', 'cream cheese '],
#  ['coffee', 'shopping bags'],
#  ['canned beer', 'UHT-milk'],
#  ['citrus fruit',
#   'sausage',
#   'yogurt',
#   'dessert',
#   'rolls/buns',
#   'pickled vegetables'],
#  ['fruit/vegetable juice', 'salty snack', 'candy', 'dental care', 'butter'],
#  ['root vegetables', 'whipped/sour cream', 'root vegetables', 'canned beer'],
#  ['root vegetables', 'long life bakery product'],
#  ['rolls/buns', 'bottled water'],
#  ['pork', 'hamburger meat'],
#  ['rolls/buns', 'softener', 'red/blush wine', 'salt', 'whole milk'],
#  ['soda', 'butter'],
#  ['specialty chocolate', 'rolls/buns', 'root vegetables', 'sugar'],
#  ['rolls/buns', 'baking powder', 'onions', 'bottled water'],
#  ['onions', 'canned beer', 'flower (seeds)'],
#  ['dessert', 'ham'],
#  ['other vegetables', 'other vegetables', 'berries'],
#  ['ice cream', 'pot plants'],
#  ['beverages', 'cream cheese '],
#  ['berries',
#   'ice cream',
#   'soda',
#   'butter',
#   'other vegetables',
#   'whipped/sour cream',
#   'white bread',
#   'cream cheese '],
#  ['yogurt', 'whipped/sour cream', 'root vegetables', 'newspapers'],
#  ['white bread', 'whole milk', 'pastry', 'shopping bags'],
#  ['fruit/vegetable juice', 'dessert'],
#  ['chicken', 'sausage', 'waffles', 'snack products', 'rolls/buns'],
#  ['frankfurter', 'pastry'],
#  ['tropical fruit', 'soda', 'rolls/buns'],
#  ['pip fruit',
#   'bottled water',
#   'cling film/bags',
#   'domestic eggs',
#   'yogurt',
#   'cat food',
#   'frozen meals'],
#  ['tropical fruit', 'newspapers'],
#  ['whole milk',
#   'yogurt',
#   'pip fruit',
#   'yogurt',
#   'rolls/buns',
#   'white wine',
#   'white bread',
#   'salt'],
#  ['sausage', 'frozen vegetables'],
#  ['whole milk', 'newspapers'],
#  ['whole milk', 'frozen vegetables'],
#  ['fruit/vegetable juice', 'vinegar'],
#  ['citrus fruit', 'shopping bags', 'chewing gum', 'cake bar'],
#  ['tropical fruit', 'white bread', 'rolls/buns'],
#  ['frankfurter', 'yogurt', 'canned beer'],
#  ['other vegetables', 'specialty chocolate'],
#  ['Instant food products', 'whipped/sour cream', 'butter', 'cake bar'],
#  ['sausage', 'pork', 'butter', 'whole milk', 'fruit/vegetable juice'],
#  ['pip fruit',
#   'whole milk',
#   'herbs',
#   'pip fruit',
#   'whipped/sour cream',
#   'frozen meals'],
#  ['margarine', 'napkins'],
#  ['salty snack', 'rolls/buns'],
#  ['root vegetables', 'white bread'],
#  ['yogurt', 'rolls/buns'],
#  ['tropical fruit', 'chicken', 'onions', 'packaged fruit/vegetables'],
#  ['whole milk', 'pasta', 'rolls/buns'],
#  ['chicken', 'frozen vegetables', 'candy'],
#  ['prosecco', 'dessert'],
#  ['tropical fruit', 'brown bread', 'whole milk'],
#  ['hamburger meat', 'yogurt'],
#  ['citrus fruit', 'whole milk', 'bottled water', 'other vegetables'],
#  ['beef', 'dessert'],
#  ['tropical fruit', 'sliced cheese'],
#  ['napkins', 'whole milk', 'chocolate marshmallow'],
#  ['citrus fruit', 'rolls/buns', 'whole milk'],
#  ['tropical fruit', 'other vegetables'],
#  ['root vegetables', 'curd'],
#  ['root vegetables', 'yogurt', 'butter', 'yogurt'],
#  ['fruit/vegetable juice', 'specialty chocolate', 'Instant food products'],
#  ['chicken', 'onions'],
#  ['whole milk', 'pastry'],
#  ['pork', 'bottled water'],
#  ['sweet spreads', 'curd', 'butter', 'soda'],
#  ['pip fruit', 'soda'],
#  ['rolls/buns', 'tropical fruit'],
#  ['rolls/buns', 'condensed milk', 'whole milk', 'soda'],
#  ['frankfurter', 'herbs'],
#  ['white bread', 'specialty bar', 'candy', 'margarine'],
#  ['butter', 'whole milk'],
#  ['whipped/sour cream', 'pasta', 'hygiene articles', 'yogurt', 'cat food'],
#  ['meat', 'whole milk'],
#  ['waffles', 'beverages'],
#  ['UHT-milk', 'other vegetables', 'dishes'],
#  ['house keeping products', 'yogurt'],
#  ['shopping bags', 'shopping bags'],
#  ['tropical fruit',
#   'other vegetables',
#   'hamburger meat',
#   'hamburger meat',
#   'popcorn',
#   'bottled beer',
#   'female sanitary products'],
#  ['fish', 'tropical fruit', 'red/blush wine', 'cream cheese '],
#  ['other vegetables',
#   'pork',
#   'soda',
#   'rolls/buns',
#   'coffee',
#   'dishes',
#   'frozen vegetables'],
#  ['frankfurter', 'soda', 'whipped/sour cream', 'hamburger meat'],
#  ['butter milk',
#   'yogurt',
#   'butter',
#   'chicken',
#   'soda',
#   'yogurt',
#   'margarine',
#   'dog food',
#   'beverages',
#   'whole milk',
#   'coffee'],
#  ['beef', 'shopping bags'],
#  ['bottled water', 'chewing gum'],
#  ['pork',
#   'other vegetables',
#   'yogurt',
#   'shopping bags',
#   'soft cheese',
#   'detergent'],
#  ['root vegetables', 'grapes'],
#  ['waffles', 'whole milk', 'rolls/buns', 'sugar'],
#  ['hamburger meat', 'pastry'],
#  ['chicken',
#   'soda',
#   'other vegetables',
#   'frozen vegetables',
#   'soda',
#   'whole milk'],
#  ['frankfurter', 'citrus fruit', 'margarine'],
#  ['soda', 'fruit/vegetable juice'],
#  ['photo/film', 'bottled beer', 'other vegetables', 'oil'],
#  ['bottled water', 'yogurt', 'newspapers', 'soda'],
#  ['pork', 'white wine'],
#  ['whipped/sour cream', 'meat spreads'],
#  ['pip fruit', 'other vegetables'],
#  ['ham', 'whole milk'],
#  ['soda', 'domestic eggs', 'sliced cheese', 'soda'],
#  ['tropical fruit', 'UHT-milk'],
#  ['salty snack', 'pickled vegetables'],
#  ['sausage', 'bottled water'],
#  ['chicken', 'other vegetables'],
#  ['yogurt', 'root vegetables'],
#  ['root vegetables', 'other vegetables'],
#  ['sausage', 'salty snack', 'cling film/bags'],
#  ['dessert', 'spread cheese'],
#  ['soda', 'beef', 'fruit/vegetable juice', 'chocolate', 'bottled beer'],
#  ['whole milk',
#   'tropical fruit',
#   'root vegetables',
#   'Instant food products',
#   'margarine'],
#  ['whipped/sour cream', 'beverages', 'hard cheese', 'dessert'],
#  ['other vegetables',
#   'yogurt',
#   'ham',
#   'whole milk',
#   'butter',
#   'whipped/sour cream',
#   'ketchup',
#   'shopping bags'],
#  ['whole milk', 'sauces'],
#  ['tropical fruit',
#   'whole milk',
#   'other vegetables',
#   'long life bakery product',
#   'white bread',
#   'frozen fruits'],
#  ['rolls/buns', 'candy'],
#  ['whole milk', 'citrus fruit'],
#  ['cream cheese ', 'rolls/buns'],
#  ['long life bakery product', 'root vegetables', 'other vegetables'],
#  ['root vegetables', 'whole milk'],
#  ['frankfurter', 'tropical fruit'],
#  ['red/blush wine', 'hamburger meat', 'frozen fish', 'soda'],
#  ['beef',
#   'tropical fruit',
#   'dessert',
#   'whole milk',
#   'long life bakery product',
#   'rum'],
#  ['tropical fruit', 'rolls/buns'],
#  ['root vegetables', 'bottled beer'],
#  ['whole milk', 'other vegetables', 'oil', 'shopping bags'],
#  ['rolls/buns', 'tropical fruit', 'coffee', 'chocolate'],
#  ['whole milk', 'tropical fruit'],
#  ['hamburger meat', 'pork'],
#  ['soda', 'yogurt'],
#  ['pork', 'spread cheese'],
#  ['pork', 'rolls/buns'],
#  ['bottled beer',
#   'tropical fruit',
#   'sliced cheese',
#   'dishes',
#   'salt',
#   'domestic eggs'],
#  ['brown bread', 'fruit/vegetable juice'],
#  ['citrus fruit', 'red/blush wine'],
#  ['cream cheese ', 'newspapers'],
#  ['yogurt', 'roll products ', 'fruit/vegetable juice'],
#  ['frankfurter', 'canned beer'],
#  ['ham', 'other vegetables'],
#  ['brown bread', 'salt'],
#  ['pip fruit', 'curd', 'pip fruit', 'prosecco'],
#  ['finished products',
#   'yogurt',
#   'brown bread',
#   'bottled water',
#   'dishes',
#   'domestic eggs'],
#  ['fruit/vegetable juice', 'flower (seeds)'],
#  ['oil', 'shopping bags'],
#  ['semi-finished bread', 'ketchup'],
#  ['misc. beverages', 'instant coffee', 'detergent', 'candy'],
#  ['frankfurter', 'frozen meals', 'dishes'],
#  ['frankfurter',
#   'pip fruit',
#   'citrus fruit',
#   'UHT-milk',
#   'bottled water',
#   'rolls/buns',
#   'fruit/vegetable juice',
#   'canned fish'],
#  ['sausage', 'butter', 'bottled water'],
#  ['frankfurter', 'chicken', 'butter', 'bottled water'],
#  ['ham', 'sausage', 'whole milk', 'whole milk', 'brown bread', 'coffee'],
#  ['white bread', 'brown bread'],
#  ['tropical fruit',
#   'canned beer',
#   'soda',
#   'rolls/buns',
#   'artif. sweetener',
#   'soda'],
#  ['pastry', 'pasta'],
#  ['rolls/buns', 'other vegetables', 'root vegetables', 'butter'],
#  ['chicken', 'soda'],
#  ['frankfurter', 'curd', 'white bread', 'rolls/buns', 'coffee'],
#  ['red/blush wine', 'bottled water', 'sweet spreads'],
#  ['rolls/buns', 'onions', 'napkins'],
#  ['canned beer', 'soda'],
#  ['root vegetables', 'frozen vegetables', 'pet care'],
#  ['other vegetables', 'frankfurter', 'newspapers', 'whole milk', 'pastry'],
#  ['coffee', 'butter milk'],
#  ['specialty bar',
#   'tropical fruit',
#   'yogurt',
#   'bottled beer',
#   'baking powder'],
#  ['beverages', 'yogurt'],
#  ['tropical fruit', 'whole milk'],
#  ['bottled water', 'hygiene articles'],
#  ['beef', 'margarine', 'other vegetables'],
#  ['pork', 'sliced cheese'],
#  ['hamburger meat', 'whole milk'],
#  ['specialty chocolate', 'soda', 'bathroom cleaner'],
#  ['pip fruit', 'other vegetables'],
#  ['root vegetables', 'citrus fruit'],
#  ['yogurt', 'newspapers'],
#  ['other vegetables', 'shopping bags', 'soda'],
#  ['canned beer', 'herbs', 'margarine'],
#  ['rolls/buns', 'citrus fruit'],
#  ['rolls/buns', 'soda'],
#  ['other vegetables', 'beef', 'soda', 'curd', 'butter'],
#  ['ice cream', 'whipped/sour cream'],
#  ['herbs', 'other vegetables', 'pot plants', 'whole milk', 'cake bar'],
#  ['ham', 'white bread'],
#  ['whole milk', 'whole milk'],
#  ['sausage',
#   'coffee',
#   'pip fruit',
#   'berries',
#   'specialty chocolate',
#   'chocolate',
#   'white bread'],
#  ['soda', 'flower (seeds)', 'jam'],
#  ['sausage', 'beverages'],
#  ['tropical fruit',
#   'whole milk',
#   'meat',
#   'other vegetables',
#   'hard cheese',
#   'domestic eggs',
#   'baking powder'],
#  ['yogurt', 'berries'],
#  ['yogurt', 'sauces'],
#  ['sausage',
#   'whisky',
#   'specialty chocolate',
#   'dishes',
#   'yogurt',
#   'napkins',
#   'detergent',
#   'pastry'],
#  ['beef', 'yogurt'],
#  ['ice cream', 'whole milk'],
#  ['frankfurter',
#   'photo/film',
#   'other vegetables',
#   'shopping bags',
#   'bottled beer'],
#  ['rolls/buns',
#   'grapes',
#   'bottled beer',
#   'sausage',
#   'salty snack',
#   'Instant food products',
#   'domestic eggs',
#   'bottled water'],
#  ['root vegetables',
#   'soda',
#   'specialty bar',
#   'other vegetables',
#   'frozen vegetables'],
#  ['yogurt', 'newspapers'],
#  ['dessert', 'domestic eggs'],
#  ['newspapers', 'salty snack'],
#  ['tropical fruit', 'soda'],
#  ['pasta', 'hamburger meat', 'whole milk', 'detergent', 'waffles', 'flour'],
#  ['sausage',
#   'chocolate marshmallow',
#   'whole milk',
#   'whole milk',
#   'other vegetables',
#   'brown bread'],
#  ['sausage', 'tropical fruit', 'misc. beverages', 'root vegetables'],
#  ['packaged fruit/vegetables', 'bottled water', 'pork', 'domestic eggs'],
#  ['yogurt', 'shopping bags'],
#  ['pickled vegetables', 'flour'],
#  ['pip fruit', 'fruit/vegetable juice'],
#  ['frankfurter', 'whipped/sour cream', 'bottled water'],
#  ['shopping bags', 'root vegetables'],
#  ['tropical fruit',
#   'whole milk',
#   'whipped/sour cream',
#   'soda',
#   'curd',
#   'curd',
#   'shopping bags'],
#  ['sausage', 'hard cheese', 'whole milk', 'whole milk', 'cake bar'],
#  ['rolls/buns', 'shopping bags', 'cat food'],
#  ['tropical fruit', 'candy'],
#  ['root vegetables', 'frozen vegetables', 'bottled water', 'cat food'],
#  ['canned beer', 'grapes', 'napkins', 'other vegetables', 'rolls/buns'],
#  ['citrus fruit', 'dessert'],
#  ['tropical fruit',
#   'citrus fruit',
#   'yogurt',
#   'frankfurter',
#   'specialty chocolate',
#   'hard cheese',
#   'whole milk',
#   'canned beer'],
#  ['root vegetables', 'pip fruit', 'instant coffee', 'brown bread'],
#  ['spread cheese', 'pork'],
#  ['soda',
#   'hygiene articles',
#   'grapes',
#   'hamburger meat',
#   'whole milk',
#   'pudding powder',
#   'butter milk',
#   'butter',
#   'pasta',
#   'yogurt'],
#  ['rolls/buns',
#   'whole milk',
#   'other vegetables',
#   'processed cheese',
#   'whipped/sour cream'],
#  ['brown bread', 'sparkling wine'],
#  ['root vegetables', 'frozen vegetables'],
#  ['other vegetables', 'white bread', 'detergent'],
#  ['candy', 'white wine'],
#  ['yogurt', 'beverages', 'brown bread'],
#  ['waffles', 'hygiene articles', 'tea'],
#  ['ice cream', 'cream', 'herbs', 'yogurt'],
#  ['chicken', 'pastry', 'candles'],
#  ['yogurt', 'root vegetables'],
#  ['yogurt', 'other vegetables', 'rolls/buns', 'herbs'],
#  ['pork', 'whole milk'],
#  ['domestic eggs', 'yogurt'],
#  ['bottled water', 'yogurt', 'tropical fruit', 'whole milk'],
#  ['other vegetables', 'white bread'],
#  ['shopping bags', 'rolls/buns'],
#  ['liver loaf',
#   'chicken',
#   'onions',
#   'rolls/buns',
#   'spread cheese',
#   'newspapers',
#   'shopping bags'],
#  ['citrus fruit', 'beef', 'misc. beverages', 'specialty fat', 'newspapers'],
#  ['rolls/buns', 'semi-finished bread'],
#  ['citrus fruit', 'misc. beverages', 'whole milk', 'pastry'],
#  ['salty snack', 'pastry', 'oil'],
#  ['brown bread',
#   'pastry',
#   'whole milk',
#   'canned beer',
#   'whipped/sour cream',
#   'shopping bags',
#   'grapes'],
#  ['frozen potato products', 'specialty cheese'],
#  ['pip fruit', 'margarine'],
#  ['citrus fruit', 'frozen vegetables', 'margarine'],
#  ['pip fruit', 'salty snack', 'pastry'],
#  ['chocolate', 'whole milk'],
#  ['curd', 'sugar'],
#  ['whole milk', 'margarine', 'soda', 'yogurt'],
#  ['bottled water', 'chocolate', 'pickled vegetables', 'liquor'],
#  ['pastry', 'baking powder', 'butter', 'margarine', 'curd', 'dishes'],
#  ['soda', 'salty snack'],
#  ['ham', 'yogurt'],
#  ['beef', 'bottled water', 'semi-finished bread', 'flour', 'sugar'],
#  ['whole milk', 'frozen vegetables', 'soda', 'UHT-milk'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['dish cleaner', 'ice cream', 'jam', 'newspapers'],
#  ['pork', 'curd', 'pudding powder', 'canned beer', 'domestic eggs'],
#  ['whole milk', 'yogurt', 'newspapers'],
#  ['bottled beer', 'specialty bar', 'baking powder'],
#  ['misc. beverages',
#   'chocolate',
#   'UHT-milk',
#   'brown bread',
#   'white bread',
#   'salty snack'],
#  ['chicken', 'root vegetables', 'shopping bags', 'citrus fruit'],
#  ['dog food',
#   'sausage',
#   'root vegetables',
#   'dessert',
#   'shopping bags',
#   'shopping bags'],
#  ['whipped/sour cream', 'yogurt'],
#  ['other vegetables', 'butter'],
#  ['other vegetables', 'turkey', 'yogurt', 'root vegetables'],
#  ['other vegetables', 'zwieback'],
#  ['brown bread', 'soda'],
#  ['frankfurter',
#   'brown bread',
#   'rolls/buns',
#   'butter milk',
#   'canned vegetables',
#   'soda'],
#  ['chicken',
#   'newspapers',
#   'other vegetables',
#   'cream cheese ',
#   'white bread',
#   'other vegetables',
#   'bottled water',
#   'rolls/buns',
#   'liquor',
#   'root vegetables',
#   'beverages',
#   'napkins',
#   'newspapers',
#   'hard cheese'],
#  ['meat', 'whole milk', 'whipped/sour cream'],
#  ['whole milk',
#   'pip fruit',
#   'hair spray',
#   'butter',
#   'processed cheese',
#   'pastry',
#   'canned beer'],
#  ['ham', 'yogurt'],
#  ['bottled beer', 'frozen vegetables', 'sliced cheese'],
#  ['berries', 'condensed milk'],
#  ['house keeping products', 'rolls/buns', 'pickled vegetables', 'curd'],
#  ['grapes', 'whole milk'],
#  ['meat', 'other vegetables'],
#  ['pastry',
#   'condensed milk',
#   'rice',
#   'tropical fruit',
#   'chocolate marshmallow'],
#  ['other vegetables', 'tropical fruit', 'specialty bar', 'sugar'],
#  ['citrus fruit', 'brown bread'],
#  ['soda', 'UHT-milk', 'newspapers', 'white bread'],
#  ['coffee', 'shopping bags'],
#  ['bottled water', 'citrus fruit'],
#  ['root vegetables', 'chicken', 'frozen vegetables', 'dishes'],
#  ['frozen vegetables',
#   'rolls/buns',
#   'rolls/buns',
#   'oil',
#   'yogurt',
#   'cling film/bags'],
#  ['pip fruit', 'whole milk'],
#  ['pork', 'soda', 'canned vegetables'],
#  ['yogurt', 'soda'],
#  ['bottled beer', 'hygiene articles'],
#  ['root vegetables', 'margarine', 'rolls/buns'],
#  ['popcorn', 'sausage', 'citrus fruit', 'pastry'],
#  ['condensed milk', 'rolls/buns', 'shopping bags', 'margarine'],
#  ['newspapers',
#   'pork',
#   'rolls/buns',
#   'root vegetables',
#   'napkins',
#   'whipped/sour cream'],
#  ['misc. beverages', 'whole milk', 'long life bakery product'],
#  ['citrus fruit', 'soda'],
#  ['other vegetables',
#   'butter',
#   'pastry',
#   'UHT-milk',
#   'soda',
#   'roll products '],
#  ['frankfurter', 'rolls/buns', 'shopping bags', 'margarine'],
#  ['frankfurter', 'liquor', 'white bread', 'domestic eggs'],
#  ['meat', 'coffee'],
#  ['specialty bar', 'soda', 'frozen vegetables', 'frozen vegetables'],
#  ['tea',
#   'flower (seeds)',
#   'yogurt',
#   'white wine',
#   'shopping bags',
#   'brown bread'],
#  ['whole milk', 'baking powder'],
#  ['cream cheese ', 'specialty chocolate'],
#  ['grapes', 'frozen meals', 'flower (seeds)'],
#  ['bottled water', 'frankfurter', 'dessert', 'root vegetables'],
#  ['yogurt', 'softener'],
#  ['margarine', 'soda'],
#  ['tropical fruit', 'cream cheese ', 'cream cheese '],
#  ['bottled beer', 'whole milk'],
#  ['other vegetables',
#   'semi-finished bread',
#   'other vegetables',
#   'rolls/buns',
#   'shopping bags',
#   'salty snack'],
#  ['soda', 'whole milk'],
#  ['coffee', 'shopping bags', 'shopping bags'],
#  ['curd', 'domestic eggs'],
#  ['yogurt', 'pastry'],
#  ['pork', 'sausage', 'whole milk', 'rolls/buns', 'napkins', 'rice'],
#  ['pastry', 'brown bread', 'yogurt'],
#  ['other vegetables', 'oil'],
#  ['cream cheese ', 'newspapers'],
#  ['sausage', 'shopping bags', 'soda', 'butter', 'dessert', 'soda'],
#  ['hard cheese', 'butter'],
#  ['whole milk', 'other vegetables'],
#  ['citrus fruit', 'flower (seeds)'],
#  ['herbs', 'citrus fruit'],
#  ['tropical fruit', 'butter milk', 'brown bread'],
#  ['tropical fruit', 'instant coffee', 'other vegetables', 'shopping bags'],
#  ['other vegetables', 'beef'],
#  ['tropical fruit', 'root vegetables', 'whole milk', 'butter milk'],
#  ['rolls/buns', 'fruit/vegetable juice'],
#  ['nut snack', 'canned beer'],
#  ['whole milk', 'other vegetables', 'other vegetables', 'sugar'],
#  ['citrus fruit', 'napkins'],
#  ['rolls/buns', 'butter milk'],
#  ['whole milk', 'root vegetables'],
#  ['tropical fruit', 'pork', 'misc. beverages', 'pickled vegetables'],
#  ['rolls/buns', 'brown bread', 'canned beer'],
#  ['tropical fruit', 'soft cheese'],
#  ['pip fruit',
#   'photo/film',
#   'frankfurter',
#   'other vegetables',
#   'other vegetables',
#   'curd',
#   'cling film/bags',
#   'waffles'],
#  ['berries', 'white bread'],
#  ['cat food', 'rolls/buns'],
#  ['tropical fruit', 'rolls/buns', 'yogurt', 'whole milk', 'soda'],
#  ['other vegetables', 'napkins'],
#  ['chicken', 'brown bread'],
#  ['newspapers', 'soups'],
#  ['rolls/buns', 'soda'],
#  ['pork', 'soda'],
#  ['UHT-milk', 'soda'],
#  ['soda', 'whole milk', 'whole milk', 'sugar'],
#  ['misc. beverages', 'spread cheese', 'oil', 'pickled vegetables'],
#  ['chicken', 'pork', 'domestic eggs', 'domestic eggs', 'white bread'],
#  ['hard cheese', 'canned beer', 'root vegetables', 'fish', 'white bread'],
#  ['root vegetables', 'coffee'],
#  ['meat', 'soda', 'whole milk', 'whipped/sour cream'],
#  ['bottled beer', 'soda'],
#  ['brown bread', 'other vegetables'],
#  ['tropical fruit', 'root vegetables'],
#  ['frozen vegetables',
#   'other vegetables',
#   'yogurt',
#   'pip fruit',
#   'berries',
#   'soda',
#   'root vegetables',
#   'candy',
#   'cereals',
#   'sliced cheese',
#   'yogurt'],
#  ['pork', 'bottled water', 'margarine', 'shopping bags', 'waffles'],
#  ['whole milk', 'bottled beer', 'curd', 'soft cheese'],
#  ['specialty chocolate', 'canned fish'],
#  ['soda', 'whole milk'],
#  ['frozen meals', 'detergent'],
#  ['root vegetables', 'soda', 'long life bakery product'],
#  ['soda', 'other vegetables'],
#  ['soda', 'other vegetables'],
#  ['pork', 'tropical fruit'],
#  ['yogurt',
#   'sausage',
#   'pork',
#   'whole milk',
#   'shopping bags',
#   'white bread',
#   'yogurt',
#   'dog food',
#   'baking powder',
#   'sliced cheese'],
#  ['seasonal products', 'frozen vegetables', 'yogurt'],
#  ['soda', 'bottled beer', 'chicken', 'yogurt'],
#  ['other vegetables', 'pip fruit', 'fruit/vegetable juice', 'berries'],
#  ['canned beer', 'sugar'],
#  ['long life bakery product', 'rolls/buns', 'UHT-milk', 'bottled water'],
#  ['curd', 'soft cheese'],
#  ['berries', 'pip fruit', 'pastry'],
#  ['curd cheese', 'soda'],
#  ['soda', 'frozen meals'],
#  ['pork', 'domestic eggs'],
#  ['whole milk', 'rolls/buns'],
#  ['tropical fruit', 'rolls/buns', 'canned beer', 'dish cleaner'],
#  ['frankfurter', 'soft cheese', 'mustard'],
#  ['chewing gum', 'whole milk', 'bottled beer', 'ready soups'],
#  ['whole milk', 'chicken', 'grapes', 'cake bar'],
#  ['butter', 'ice cream'],
#  ['root vegetables', 'other vegetables', 'frozen vegetables'],
#  ['citrus fruit', 'sausage', 'whole milk', 'canned beer'],
#  ['female sanitary products', 'rolls/buns'],
#  ['whole milk', 'house keeping products'],
#  ['frankfurter', 'brandy'],
#  ['whole milk', 'sausage', 'pet care', 'yogurt'],
#  ['berries', 'other vegetables'],
#  ['beef', 'curd', 'frozen meals'],
#  ['tropical fruit', 'UHT-milk', 'napkins', 'whole milk'],
#  ['yogurt',
#   'rolls/buns',
#   'other vegetables',
#   'citrus fruit',
#   'butter',
#   'root vegetables',
#   'rolls/buns'],
#  ['whole milk', 'cream cheese '],
#  ['whole milk', 'bottled water'],
#  ['citrus fruit', 'soda'],
#  ['frozen vegetables', 'domestic eggs'],
#  ['citrus fruit', 'light bulbs'],
#  ['butter',
#   'pip fruit',
#   'domestic eggs',
#   'beef',
#   'chewing gum',
#   'tropical fruit',
#   'coffee',
#   'bottled beer',
#   'mustard'],
#  ['shopping bags', 'frozen meals'],
#  ['whole milk', 'root vegetables'],
#  ['yogurt', 'whole milk'],
#  ['other vegetables', 'yogurt', 'whole milk', 'spread cheese'],
#  ['beef', 'newspapers', 'bottled beer'],
#  ['canned beer', 'berries', 'male cosmetics', 'fruit/vegetable juice'],
#  ['misc. beverages', 'white bread', 'coffee', 'yogurt'],
#  ['canned beer', 'citrus fruit'],
#  ['red/blush wine', 'salty snack'],
#  ['whole milk', 'beef', 'citrus fruit', 'newspapers', 'bottled water'],
#  ['sausage', 'bottled water'],
#  ['white bread', 'frozen vegetables'],
#  ['whole milk', 'root vegetables', 'canned vegetables'],
#  ['other vegetables', 'sliced cheese'],
#  ['frozen vegetables', 'whole milk'],
#  ['pork', 'packaged fruit/vegetables', 'chocolate'],
#  ['curd', 'beef', 'spices', 'house keeping products'],
#  ['root vegetables', 'brown bread'],
#  ['bottled water', 'tropical fruit'],
#  ['coffee', 'domestic eggs'],
#  ['rolls/buns', 'other vegetables'],
#  ['frankfurter',
#   'sweet spreads',
#   'frozen vegetables',
#   'herbs',
#   'long life bakery product'],
#  ['bottled beer', 'whole milk', 'UHT-milk', 'chocolate'],
#  ['soda', 'margarine'],
#  ['cake bar', 'bottled beer'],
#  ['soda',
#   'liquor',
#   'waffles',
#   'detergent',
#   'bottled water',
#   'whole milk',
#   'other vegetables',
#   'white bread'],
#  ['finished products',
#   'newspapers',
#   'napkins',
#   'whipped/sour cream',
#   'cleaner'],
#  ['napkins', 'napkins'],
#  ['other vegetables', 'rolls/buns'],
#  ['citrus fruit', 'whipped/sour cream'],
#  ['pip fruit', 'whipped/sour cream'],
#  ['whole milk',
#   'whole milk',
#   'turkey',
#   'pork',
#   'dog food',
#   'whole milk',
#   'sparkling wine',
#   'rolls/buns',
#   'soda',
#   'bottled water',
#   'bottled water',
#   'canned beer'],
#  ['chicken', 'chocolate', 'pip fruit', 'shopping bags'],
#  ['other vegetables', 'soda'],
#  ['soda', 'whipped/sour cream'],
#  ['specialty chocolate', 'beverages', 'brown bread', 'pasta'],
#  ['bottled water', 'onions'],
#  ['rolls/buns', 'margarine'],
#  ['bottled beer', 'fruit/vegetable juice', 'rolls/buns'],
#  ['hard cheese', 'rolls/buns', 'specialty bar', 'newspapers'],
#  ['pip fruit', 'root vegetables', 'whipped/sour cream', 'cling film/bags'],
#  ['citrus fruit', 'syrup'],
#  ['rolls/buns',
#   'soft cheese',
#   'fruit/vegetable juice',
#   'baking powder',
#   'pickled vegetables'],
#  ['citrus fruit', 'brown bread', 'pasta', 'specialty chocolate', 'oil'],
#  ['hamburger meat', 'other vegetables'],
#  ['bottled water', 'yogurt', 'beef', 'berries', 'chocolate', 'butter'],
#  ['whole milk',
#   'citrus fruit',
#   'shopping bags',
#   'white wine',
#   'soda',
#   'yogurt'],
#  ['tropical fruit',
#   'frozen potato products',
#   'other vegetables',
#   'domestic eggs',
#   'curd cheese'],
#  ['whole milk',
#   'pastry',
#   'hard cheese',
#   'tropical fruit',
#   'other vegetables',
#   'sugar',
#   'bottled water'],
#  ['soda', 'whole milk'],
#  ['rolls/buns', 'canned beer', 'brown bread', 'dessert'],
#  ['oil', 'coffee'],
#  ['bottled water',
#   'other vegetables',
#   'tropical fruit',
#   'ice cream',
#   'chocolate',
#   'pork',
#   'shopping bags',
#   'salt',
#   'jam'],
#  ['cereals', 'soda'],
#  ['chicken', 'frozen meals', 'napkins'],
#  ['citrus fruit', 'white bread', 'frozen potato products', 'whole milk'],
#  ['sausage', 'root vegetables'],
#  ['bottled beer', 'oil', 'whole milk', 'dishes'],
#  ['white bread', 'mayonnaise'],
#  ['butter', 'mustard'],
#  ['hamburger meat', 'candy', 'pip fruit', 'baking powder', 'canned fish'],
#  ['ice cream',
#   'hamburger meat',
#   'rolls/buns',
#   'shopping bags',
#   'whole milk',
#   'red/blush wine',
#   'soft cheese'],
#  ['beef', 'butter milk'],
#  ['sausage',
#   'bottled beer',
#   'dessert',
#   'butter',
#   'cream cheese ',
#   'other vegetables',
#   'canned beer',
#   'brown bread'],
#  ['root vegetables',
#   'ham',
#   'butter',
#   'brown bread',
#   'pastry',
#   'spread cheese'],
#  ['sausage', 'domestic eggs'],
#  ['root vegetables', 'beef', 'sweet spreads', 'whole milk', 'newspapers'],
#  ['pip fruit', 'specialty bar', 'chocolate'],
#  ['frankfurter', 'canned beer'],
#  ['ice cream', 'chewing gum'],
#  ['beef', 'whole milk', 'frozen meals'],
#  ['other vegetables',
#   'white bread',
#   'whole milk',
#   'domestic eggs',
#   'canned fruit',
#   'soda',
#   'butter'],
#  ['soda', 'detergent'],
#  ['other vegetables', 'onions', 'shopping bags'],
#  ['soda', 'citrus fruit', 'soda', 'domestic eggs'],
#  ['whole milk',
#   'butter milk',
#   'other vegetables',
#   'rolls/buns',
#   'cleaner',
#   'bottled beer',
#   'soda',
#   'bottled water'],
#  ['bottled beer', 'sliced cheese'],
#  ['tropical fruit', 'dessert'],
#  ['canned beer', 'root vegetables'],
#  ['bottled water', 'soda'],
#  ['pip fruit', 'rolls/buns', 'soda'],
#  ['root vegetables', 'hamburger meat', 'root vegetables', 'bottled beer'],
#  ['sparkling wine', 'other vegetables', 'waffles', 'meat spreads'],
#  ['whipped/sour cream', 'specialty chocolate'],
#  ['berries', 'white bread'],
#  ['hamburger meat', 'citrus fruit', 'specialty chocolate', 'other vegetables'],
#  ['butter', 'seasonal products', 'fruit/vegetable juice'],
#  ['brown bread', 'pastry'],
#  ['soda', 'shopping bags'],
#  ['citrus fruit', 'root vegetables'],
#  ['whole milk', 'pip fruit', 'bottled water', 'napkins', 'honey'],
#  ['butter', 'coffee', 'soda', 'pastry'],
#  ['whole milk', 'soft cheese'],
#  ['butter', 'shopping bags'],
#  ['finished products', 'liquor'],
#  ['mayonnaise',
#   'candy',
#   'rolls/buns',
#   'bottled beer',
#   'domestic eggs',
#   'newspapers'],
#  ['pip fruit', 'shopping bags'],
#  ['sausage', 'chocolate'],
#  ['citrus fruit', 'beef', 'yogurt', 'whipped/sour cream'],
#  ['whole milk', 'brown bread'],
#  ['root vegetables',
#   'citrus fruit',
#   'root vegetables',
#   'misc. beverages',
#   'sliced cheese',
#   'packaged fruit/vegetables',
#   'yogurt',
#   'whipped/sour cream'],
#  ['pip fruit', 'waffles'],
#  ['other vegetables',
#   'citrus fruit',
#   'specialty chocolate',
#   'napkins',
#   'newspapers'],
#  ['frozen fish', 'specialty chocolate'],
#  ['beverages', 'sausage'],
#  ['rolls/buns', 'whole milk', 'white bread', 'popcorn'],
#  ['grapes', 'rolls/buns'],
#  ['sugar', 'canned vegetables', 'flour', 'bottled water', 'salty snack'],
#  ['candy',
#   'citrus fruit',
#   'dessert',
#   'rolls/buns',
#   'root vegetables',
#   'canned fish'],
#  ['brown bread', 'detergent'],
#  ['candles', 'whole milk'],
#  ['misc. beverages', 'coffee'],
#  ['coffee', 'oil'],
#  ['yogurt', 'roll products '],
#  ['soda',
#   'yogurt',
#   'curd cheese',
#   'root vegetables',
#   'rolls/buns',
#   'semi-finished bread'],
#  ['rolls/buns', 'pastry'],
#  ['grapes', 'chicken', 'bottled beer', 'root vegetables'],
#  ['softener',
#   'root vegetables',
#   'whole milk',
#   'soda',
#   'chocolate',
#   'yogurt',
#   'waffles',
#   'beverages'],
#  ['sliced cheese', 'pip fruit'],
#  ['yogurt', 'whole milk', 'yogurt', 'chewing gum'],
#  ['white bread', 'bottled water', 'ready soups', 'curd'],
#  ['whole milk', 'oil'],
#  ['pastry',
#   'sausage',
#   'sausage',
#   'soda',
#   'rolls/buns',
#   'sugar',
#   'cat food',
#   'soda',
#   'other vegetables',
#   'whole milk',
#   'softener'],
#  ['tropical fruit', 'hygiene articles', 'candles'],
#  ['ham', 'pickled vegetables', 'shopping bags'],
#  ['frankfurter', 'whole milk'],
#  ['whole milk', 'yogurt', 'semi-finished bread'],
#  ['rolls/buns', 'frozen meals'],
#  ['shopping bags', 'misc. beverages'],
#  ['pork', 'beef', 'yogurt'],
#  ['soft cheese', 'bottled water'],
#  ['tropical fruit', 'butter milk'],
#  ['sausage', 'dessert'],
#  ['ham',
#   'fruit/vegetable juice',
#   'brown bread',
#   'long life bakery product',
#   'specialty cheese'],
#  ['yogurt', 'shopping bags'],
#  ['finished products', 'domestic eggs'],
#  ['specialty bar', 'whole milk'],
#  ['rolls/buns',
#   'UHT-milk',
#   'butter',
#   'tropical fruit',
#   'salty snack',
#   'other vegetables',
#   'margarine',
#   'specialty bar'],
#  ['frankfurter', 'butter', 'specialty bar', 'yogurt'],
#  ['tropical fruit', 'root vegetables', 'cat food', 'other vegetables'],
#  ['beef', 'domestic eggs'],
#  ['tropical fruit', 'salt'],
#  ['citrus fruit', 'bottled beer'],
#  ['domestic eggs', 'fruit/vegetable juice'],
#  ['chicken',
#   'beef',
#   'pork',
#   'beef',
#   'newspapers',
#   'dessert',
#   'margarine',
#   'brown bread',
#   'newspapers'],
#  ['meat', 'chicken', 'yogurt', 'pip fruit'],
#  ['syrup', 'waffles'],
#  ['sauces', 'yogurt'],
#  ['pip fruit', 'other vegetables', 'semi-finished bread', 'sliced cheese'],
#  ['grapes', 'root vegetables', 'shopping bags'],
#  ['canned beer', 'citrus fruit', 'brown bread', 'long life bakery product'],
#  ['whole milk',
#   'soda',
#   'root vegetables',
#   'pastry',
#   'specialty fat',
#   'bottled water',
#   'napkins',
#   'tropical fruit'],
#  ['turkey', 'onions'],
#  ['whole milk', 'sugar'],
#  ['whole milk',
#   'citrus fruit',
#   'dog food',
#   'grapes',
#   'pastry',
#   'bottled water'],
#  ['other vegetables', 'fruit/vegetable juice'],
#  ['whole milk',
#   'sausage',
#   'pork',
#   'yogurt',
#   'whole milk',
#   'frozen meals',
#   'butter'],
#  ['tropical fruit',
#   'citrus fruit',
#   'rolls/buns',
#   'citrus fruit',
#   'frozen fish'],
#  ['tropical fruit', 'meat', 'whole milk', 'candles'],
#  ['meat', 'cling film/bags', 'curd'],
#  ['canned beer', 'red/blush wine', 'brown bread', 'instant coffee'],
#  ['rolls/buns',
#   'specialty chocolate',
#   'napkins',
#   'onions',
#   'rice',
#   'rolls/buns',
#   'butter milk',
#   'dental care'],
#  ['sausage', 'pasta'],
#  ['canned beer', 'margarine', 'chocolate'],
#  ['pastry', 'frankfurter', 'waffles', 'ice cream'],
#  ['sugar', 'bottled water'],
#  ['canned beer', 'coffee'],
#  ['condensed milk', 'onions'],
#  ['citrus fruit', 'butter', 'UHT-milk'],
#  ['ham', 'rum'],
#  ['packaged fruit/vegetables', 'flour'],
#  ['citrus fruit', 'semi-finished bread', 'yogurt'],
#  ['sausage', 'specialty chocolate'],
#  ['UHT-milk', 'cooking chocolate'],
#  ['white bread', 'jam'],
#  ['whole milk', 'curd'],
#  ['butter milk', 'soda', 'seasonal products'],
#  ['dessert',
#   'shopping bags',
#   'whole milk',
#   'sliced cheese',
#   'bottled beer',
#   'whole milk',
#   'whole milk',
#   'other vegetables',
#   'detergent',
#   'flour'],
#  ['pastry', 'rolls/buns'],
#  ['photo/film', 'brown bread'],
#  ['hard cheese', 'pastry'],
#  ['beef',
#   'citrus fruit',
#   'specialty bar',
#   'white bread',
#   'soda',
#   'vinegar',
#   'long life bakery product',
#   'domestic eggs'],
#  ['yogurt', 'whipped/sour cream'],
#  ['photo/film', 'beverages', 'bottled beer'],
#  ['ham', 'whipped/sour cream', 'newspapers'],
#  ['mustard', 'brown bread'],
#  ['beef', 'white bread', 'frozen potato products'],
#  ['whole milk', 'other vegetables'],
#  ['canned beer', 'sliced cheese'],
#  ['frankfurter', 'pastry', 'misc. beverages'],
#  ['soda', 'ham', 'butter milk', 'domestic eggs', 'soda'],
#  ['soda', 'canned beer'],
#  ['yogurt', 'margarine'],
#  ['grapes', 'hard cheese', 'detergent', 'soda'],
#  ['ice cream', 'pork', 'onions', 'sliced cheese', 'flour'],
#  ['sausage',
#   'white wine',
#   'root vegetables',
#   'photo/film',
#   'whipped/sour cream'],
#  ['pasta', 'canned beer'],
#  ['rolls/buns', 'butter', 'bottled beer', 'grapes', 'bottled water'],
#  ['chicken',
#   'rolls/buns',
#   'whipped/sour cream',
#   'waffles',
#   'rolls/buns',
#   'whole milk',
#   'margarine',
#   'soda',
#   'salty snack',
#   'soda',
#   'canned beer'],
#  ['whipped/sour cream', 'UHT-milk', 'shopping bags', 'curd'],
#  ['butter milk', 'other vegetables', 'other vegetables', 'rolls/buns'],
#  ['salty snack', 'root vegetables'],
#  ['yogurt', 'curd', 'shopping bags', 'pastry', 'coffee'],
#  ['root vegetables', 'margarine', 'bottled water'],
#  ['shopping bags', 'waffles'],
#  ['butter', 'roll products '],
#  ['condensed milk',
#   'canned beer',
#   'other vegetables',
#   'bottled beer',
#   'bottled water',
#   'soda'],
#  ['sausage', 'sausage', 'bottled beer', 'spread cheese'],
#  ['other vegetables',
#   'curd',
#   'dog food',
#   'abrasive cleaner',
#   'processed cheese'],
#  ['newspapers', 'pip fruit', 'dishes'],
#  ['whole milk', 'cling film/bags'],
#  ['cleaner', 'butter milk', 'misc. beverages', 'hard cheese'],
#  ['rolls/buns', 'pork', 'hard cheese', 'other vegetables', 'cream cheese '],
#  ['ham',
#   'whole milk',
#   'other vegetables',
#   'beverages',
#   'soda',
#   'white bread',
#   'tropical fruit',
#   'sugar',
#   'sugar'],
#  ['citrus fruit', 'other vegetables'],
#  ['frankfurter', 'margarine'],
#  ['meat', 'soda'],
#  ['brown bread', 'tropical fruit'],
#  ['condensed milk',
#   'finished products',
#   'yogurt',
#   'whole milk',
#   'bottled beer',
#   'bottled water',
#   'roll products ',
#   'waffles'],
#  ['sausage', 'processed cheese'],
#  ['whipped/sour cream', 'yogurt'],
#  ['soda', 'shopping bags'],
#  ['frozen vegetables',
#   'sausage',
#   'whole milk',
#   'frozen vegetables',
#   'onions',
#   'rolls/buns',
#   'other vegetables',
#   'oil',
#   'frozen fish',
#   'hard cheese',
#   'baking powder'],
#  ['meat', 'oil', 'other vegetables', 'margarine', 'pasta'],
#  ['whole milk', 'specialty cheese'],
#  ['specialty chocolate', 'pasta', 'soda', 'long life bakery product'],
#  ['sausage', 'dog food', 'bottled beer', 'bottled water'],
#  ['sausage', 'shopping bags', 'frozen meals', 'tropical fruit'],
#  ['citrus fruit', 'other vegetables'],
#  ['beverages', 'beverages', 'sugar', 'pasta', 'domestic eggs'],
#  ['butter', 'chocolate'],
#  ['soda', 'cling film/bags'],
#  ['candy', 'soda'],
#  ['UHT-milk', 'soft cheese'],
#  ['rolls/buns', 'salty snack', 'bottled water', 'shopping bags'],
#  ['turkey', 'shopping bags'],
#  ['dessert', 'condensed milk', 'rolls/buns', 'shopping bags'],
#  ['soda',
#   'coffee',
#   'onions',
#   'soda',
#   'canned fruit',
#   'white bread',
#   'soft cheese',
#   'processed cheese',
#   'soda',
#   'shopping bags'],
#  ['tropical fruit', 'grapes', 'rolls/buns', 'other vegetables'],
#  ['tropical fruit', 'yogurt', 'berries', 'canned beer'],
#  ['other vegetables', 'UHT-milk', 'whipped/sour cream', 'yogurt'],
#  ['frozen vegetables', 'other vegetables'],
#  ['butter', 'candy'],
#  ['root vegetables', 'frozen vegetables'],
#  ['chicken', 'butter'],
#  ['citrus fruit',
#   'tropical fruit',
#   'dessert',
#   'skin care',
#   'pip fruit',
#   'packaged fruit/vegetables'],
#  ['beef', 'frankfurter', 'margarine', 'curd', 'whole milk', 'margarine'],
#  ['soda', 'frozen meals', 'bottled beer'],
#  ['citrus fruit', 'coffee'],
#  ['other vegetables', 'chewing gum'],
#  ['canned beer', 'dessert', 'fruit/vegetable juice'],
#  ['pork', 'turkey', 'pot plants', 'whole milk', 'soda', 'dishes'],
#  ['grapes', 'other vegetables'],
#  ['chicken', 'pastry'],
#  ['sausage',
#   'processed cheese',
#   'pastry',
#   'baking powder',
#   'specialty cheese',
#   'liqueur'],
#  ['ham', 'napkins'],
#  ['white wine', 'specialty bar', 'specialty chocolate'],
#  ['soda', 'red/blush wine'],
#  ['berries', 'domestic eggs'],
#  ['UHT-milk', 'herbs', 'butter', 'oil'],
#  ['sausage', 'coffee'],
#  ['sugar', 'other vegetables', 'tea', 'coffee'],
#  ['frozen dessert', 'cream cheese '],
#  ['rolls/buns', 'yogurt'],
#  ['rolls/buns',
#   'fruit/vegetable juice',
#   'frozen vegetables',
#   'whipped/sour cream'],
#  ['yogurt', 'coffee'],
#  ['pork', 'root vegetables'],
#  ['sausage', 'grapes', 'sliced cheese', 'napkins'],
#  ['ice cream', 'whole milk', 'whole milk', 'shopping bags'],
#  ['hamburger meat', 'fruit/vegetable juice', 'coffee', 'berries'],
#  ['pip fruit', 'shopping bags'],
#  ['sausage', 'curd'],
#  ['whole milk', 'domestic eggs', 'canned vegetables', 'flower (seeds)'],
#  ['rolls/buns', 'hard cheese', 'rolls/buns', 'flour'],
#  ['organic sausage', 'frozen meals', 'sugar'],
#  ['whole milk', 'onions', 'pickled vegetables'],
#  ['citrus fruit', 'frozen meals', 'other vegetables', 'bottled beer'],
#  ['specialty bar',
#   'sugar',
#   'tropical fruit',
#   'yogurt',
#   'tropical fruit',
#   'curd',
#   'semi-finished bread',
#   'soda'],
#  ['sausage',
#   'tropical fruit',
#   'other vegetables',
#   'tropical fruit',
#   'white bread',
#   'mayonnaise',
#   'butter'],
#  ['bottled water', 'pastry'],
#  ['UHT-milk', 'canned fish', 'root vegetables', 'waffles'],
#  ['pork', 'hamburger meat', 'yogurt', 'other vegetables', 'domestic eggs'],
#  ['cream cheese ',
#   'pork',
#   'pip fruit',
#   'citrus fruit',
#   'chicken',
#   'other vegetables',
#   'other vegetables',
#   'brown bread',
#   'curd',
#   'specialty chocolate',
#   'pastry',
#   'whole milk',
#   'soda'],
#  ['shopping bags', 'tropical fruit', 'red/blush wine'],
#  ['other vegetables', 'sliced cheese'],
#  ['butter', 'whole milk'],
#  ['white wine', 'sauces'],
#  ['oil', 'canned fish'],
#  ['other vegetables', 'margarine', 'brown bread'],
#  ['whole milk', 'misc. beverages'],
#  ['rolls/buns', 'seasonal products'],
#  ['other vegetables', 'liquor', 'whole milk', 'butter milk'],
#  ['tropical fruit', 'root vegetables'],
#  ['red/blush wine', 'frozen meals', 'canned fruit'],
#  ['other vegetables', 'whole milk', 'softener'],
#  ['pork', 'cake bar', 'napkins', 'flower soil/fertilizer'],
#  ['citrus fruit', 'cereals'],
#  ['specialty bar', 'cleaner'],
#  ['artif. sweetener', 'whole milk'],
#  ['pork', 'pastry'],
#  ['dessert', 'tidbits', 'rolls/buns', 'cream cheese '],
#  ['coffee', 'other vegetables', 'specialty cheese'],
#  ['salt',
#   'frozen potato products',
#   'citrus fruit',
#   'domestic eggs',
#   'shopping bags',
#   'butter milk'],
#  ['white bread', 'specialty chocolate'],
#  ['curd',
#   'other vegetables',
#   'root vegetables',
#   'ice cream',
#   'hygiene articles',
#   'whole milk',
#   'butter',
#   'butter',
#   'rolls/buns',
#   'dessert',
#   'dental care'],
#  ['sausage', 'citrus fruit', 'onions', 'pastry', 'mustard'],
#  ['whole milk', 'cream cheese ', 'semi-finished bread'],
#  ['condensed milk', 'hard cheese'],
#  ['dessert', 'house keeping products'],
#  ['hard cheese', 'yogurt'],
#  ['sausage', 'whole milk', 'rolls/buns', 'bottled beer'],
#  ['whipped/sour cream', 'other vegetables'],
#  ['frankfurter', 'shopping bags'],
#  ['butter', 'brown bread'],
#  ['photo/film',
#   'whole milk',
#   'yogurt',
#   'whole milk',
#   'white bread',
#   'pot plants',
#   'dessert'],
#  ['sausage', 'rolls/buns'],
#  ['root vegetables', 'newspapers'],
#  ['meat', 'citrus fruit', 'root vegetables', 'hamburger meat', 'photo/film'],
#  ['other vegetables',
#   'cookware',
#   'canned beer',
#   'canned beer',
#   'frozen vegetables',
#   'butter',
#   'ice cream',
#   'bottled water'],
#  ['chicken', 'soda', 'pastry', 'sliced cheese'],
#  ['tropical fruit',
#   'root vegetables',
#   'yogurt',
#   'sausage',
#   'ham',
#   'rolls/buns'],
#  ['beverages',
#   'sausage',
#   'oil',
#   'whole milk',
#   'citrus fruit',
#   'butter',
#   'whole milk'],
#  ['butter milk', 'spices'],
#  ['finished products', 'spices', 'rolls/buns', 'ice cream'],
#  ['UHT-milk', 'fish'],
#  ['rolls/buns', 'hamburger meat'],
#  ['finished products', 'rolls/buns', 'oil', 'frozen vegetables'],
#  ['tropical fruit', 'coffee', 'newspapers'],
#  ['soda', 'other vegetables', 'bottled water', 'snack products'],
#  ['other vegetables', 'shopping bags'],
#  ['white bread', 'shopping bags'],
#  ['misc. beverages', 'yogurt'],
#  ['UHT-milk', 'napkins', 'frozen vegetables', 'whipped/sour cream'],
#  ['bottled water', 'newspapers', 'specialty bar', 'bottled water'],
#  ['whole milk', 'butter', 'onions', 'bottled water', 'cream cheese '],
#  ['pork', 'bottled water'],
#  ['root vegetables', 'chicken'],
#  ['salty snack', 'soups'],
#  ['margarine', 'rolls/buns'],
#  ['pastry', 'soda'],
#  ['citrus fruit', 'ice cream', 'butter', 'shopping bags'],
#  ['tropical fruit', 'chocolate marshmallow', 'napkins', 'bottled water'],
#  ['yogurt', 'hygiene articles'],
#  ['butter', 'rolls/buns'],
#  ['meat', 'root vegetables', 'coffee', 'chewing gum'],
#  ['bottled beer',
#   'pork',
#   'hygiene articles',
#   'domestic eggs',
#   'pickled vegetables'],
#  ['herbs', 'dessert', 'yogurt'],
#  ['whole milk', 'long life bakery product', 'soda', 'root vegetables'],
#  ['whole milk',
#   'citrus fruit',
#   'pip fruit',
#   'butter',
#   'grapes',
#   'ice cream',
#   'margarine',
#   'whipped/sour cream'],
#  ['soft cheese', 'flower (seeds)'],
#  ['canned fruit', 'whipped/sour cream'],
#  ['chicken', 'other vegetables', 'frozen meals'],
#  ['frankfurter', 'pip fruit'],
#  ['citrus fruit', 'whole milk', 'rolls/buns'],
#  ['whole milk', 'packaged fruit/vegetables', 'abrasive cleaner', 'napkins'],
#  ['rolls/buns', 'napkins'],
#  ['root vegetables', 'spread cheese'],
#  ['other vegetables',
#   'herbs',
#   'salty snack',
#   'brown bread',
#   'yogurt',
#   'canned beer',
#   'prosecco'],
#  ['other vegetables',
#   'frankfurter',
#   'whole milk',
#   'sausage',
#   'misc. beverages',
#   'margarine',
#   'yogurt',
#   'frozen meals',
#   'cat food'],
#  ['sausage', 'whipped/sour cream', 'rice', 'margarine'],
#  ['domestic eggs',
#   'whole milk',
#   'onions',
#   'fruit/vegetable juice',
#   'rolls/buns',
#   'sugar',
#   'mustard',
#   'rolls/buns'],
#  ['tropical fruit', 'citrus fruit', 'domestic eggs', 'rolls/buns'],
#  ['beverages', 'pork'],
#  ['oil', 'whole milk'],
#  ['whole milk', 'specialty cheese'],
#  ['canned beer', 'shopping bags'],
#  ['whole milk', 'light bulbs'],
#  ['dessert', 'tropical fruit', 'pip fruit', 'hard cheese', 'specialty fat'],
#  ['whipped/sour cream', 'soft cheese'],
#  ['hygiene articles', 'semi-finished bread'],
#  ['root vegetables', 'soda', 'other vegetables'],
#  ['waffles', 'butter milk', 'white wine', 'domestic eggs', 'dishes'],
#  ['frankfurter',
#   'chicken',
#   'other vegetables',
#   'processed cheese',
#   'dessert',
#   'soda'],
#  ['sausage', 'bottled water'],
#  ['pip fruit', 'root vegetables', 'root vegetables', 'beverages'],
#  ['other vegetables',
#   'pickled vegetables',
#   'yogurt',
#   'UHT-milk',
#   'soft cheese',
#   'long life bakery product',
#   'flower (seeds)'],
#  ['rice', 'bottled beer'],
#  ['tropical fruit', 'meat', 'hard cheese', 'jam'],
#  ['yogurt', 'red/blush wine'],
#  ['chicken', 'cream cheese ', 'napkins'],
#  ['sausage', 'house keeping products'],
#  ['herbs', 'domestic eggs'],
#  ['bottled beer', 'Instant food products'],
#  ['pastry', 'rolls/buns'],
#  ['chicken', 'soda', 'dishes'],
#  ['rolls/buns', 'yogurt'],
#  ['canned beer', 'white bread'],
#  ['bottled beer', 'whole milk', 'salty snack', 'other vegetables'],
#  ['chicken', 'yogurt'],
#  ['whipped/sour cream', 'roll products '],
#  ['pot plants', 'pip fruit'],
#  ['sausage', 'soda', 'frozen vegetables'],
#  ['root vegetables', 'bottled water'],
#  ['fruit/vegetable juice',
#   'shopping bags',
#   'root vegetables',
#   'hard cheese',
#   'yogurt'],
#  ['citrus fruit', 'butter', 'rolls/buns'],
#  ['whole milk', 'pastry'],
#  ['pip fruit', 'detergent'],
#  ['canned beer', 'whole milk', 'bottled beer'],
#  ['pasta',
#   'rolls/buns',
#   'tropical fruit',
#   'margarine',
#   'canned fish',
#   'pastry',
#   'yogurt'],
#  ['frankfurter', 'whole milk'],
#  ['hamburger meat', 'other vegetables'],
#  ['rolls/buns', 'whipped/sour cream', 'dishes'],
#  ['sausage', 'spread cheese', 'white wine', 'root vegetables', 'candy'],
#  ['citrus fruit',
#   'tropical fruit',
#   'pork',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'flower (seeds)'],
#  ['whole milk', 'chocolate marshmallow', 'rolls/buns'],
#  ['yogurt', 'frozen vegetables'],
#  ['whole milk', 'pork', 'rolls/buns', 'yogurt'],
#  ['whole milk', 'sugar', 'pastry', 'canned beer'],
#  ['meat',
#   'sausage',
#   'hamburger meat',
#   'baking powder',
#   'pastry',
#   'brown bread'],
#  ['other vegetables', 'rolls/buns'],
#  ['pork', 'root vegetables', 'napkins', 'pastry'],
#  ['brown bread', 'whole milk'],
#  ['white wine', 'waffles'],
#  ['sausage', 'curd', 'whipped/sour cream', 'whipped/sour cream'],
#  ['dessert', 'pastry', 'butter', 'pickled vegetables', 'margarine'],
#  ['tropical fruit', 'cocoa drinks'],
#  ['newspapers', 'salty snack'],
#  ['hard cheese', 'salty snack'],
#  ['rolls/buns', 'red/blush wine', 'canned beer'],
#  ['candy', 'berries', 'mustard'],
#  ['other vegetables', 'rolls/buns'],
#  ['long life bakery product', 'frankfurter', 'other vegetables', 'oil'],
#  ['hamburger meat', 'butter'],
#  ['tropical fruit', 'rolls/buns'],
#  ['pip fruit', 'skin care'],
#  ['long life bakery product', 'waffles', 'canned vegetables', 'soft cheese'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['canned beer', 'ice cream'],
#  ['ham', 'chocolate'],
#  ['tropical fruit', 'hygiene articles'],
#  ['packaged fruit/vegetables', 'rolls/buns'],
#  ['rolls/buns', 'whipped/sour cream'],
#  ['bottled beer', 'curd'],
#  ['curd', 'frozen vegetables'],
#  ['sausage', 'rolls/buns'],
#  ['citrus fruit', 'other vegetables'],
#  ['specialty cheese', 'onions'],
#  ['pastry', 'specialty bar', 'mustard', 'flour', 'yogurt'],
#  ['misc. beverages', 'rice', 'soda'],
#  ['pork', 'pip fruit', 'frozen meals', 'grapes', 'pastry', 'canned beer'],
#  ['finished products', 'pip fruit', 'root vegetables', 'canned fruit'],
#  ['soft cheese', 'bottled beer'],
#  ['mayonnaise', 'root vegetables', 'processed cheese', 'coffee'],
#  ['citrus fruit', 'citrus fruit', 'soda'],
#  ['bottled beer', 'soda'],
#  ['chicken',
#   'meat',
#   'chewing gum',
#   'bottled beer',
#   'baking powder',
#   'shopping bags'],
#  ['pork', 'rolls/buns', 'specialty bar', 'hygiene articles'],
#  ['citrus fruit', 'waffles', 'female sanitary products'],
#  ['waffles', 'curd'],
#  ['soups', 'whole milk', 'beef', 'bottled beer'],
#  ['syrup', 'whole milk'],
#  ['whole milk', 'whole milk'],
#  ['specialty chocolate',
#   'citrus fruit',
#   'bottled water',
#   'whole milk',
#   'white wine',
#   'rolls/buns'],
#  ['specialty bar', 'condensed milk'],
#  ['misc. beverages', 'frankfurter', 'salt', 'curd'],
#  ['yogurt', 'processed cheese'],
#  ['rolls/buns', 'soda', 'chocolate'],
#  ['bottled water', 'long life bakery product', 'root vegetables', 'mustard'],
#  ['napkins', 'soda'],
#  ['packaged fruit/vegetables', 'chewing gum', 'ham', 'condensed milk', 'soda'],
#  ['ice cream', 'beef', 'yogurt', 'canned beer'],
#  ['cereals', 'frozen vegetables'],
#  ['other vegetables', 'roll products ', 'whole milk', 'canned vegetables'],
#  ['bottled beer', 'instant coffee'],
#  ['sausage',
#   'chicken',
#   'bottled beer',
#   'whole milk',
#   'pastry',
#   'shopping bags'],
#  ['rolls/buns', 'grapes', 'curd', 'rolls/buns'],
#  ['pip fruit', 'sugar'],
#  ['other vegetables', 'bottled beer'],
#  ['tropical fruit', 'pastry', 'cream cheese '],
#  ['sausage', 'ham', 'shopping bags', 'whole milk', 'butter'],
#  ['ham', 'sausage', 'detergent', 'whipped/sour cream', 'yogurt', 'dishes'],
#  ['hamburger meat',
#   'dessert',
#   'whipped/sour cream',
#   'newspapers',
#   'domestic eggs'],
#  ['sausage', 'frozen vegetables'],
#  ['canned beer', 'whipped/sour cream', 'misc. beverages'],
#  ['newspapers', 'processed cheese'],
#  ['soda', 'chicken', 'soda', 'berries', 'roll products ', 'soda'],
#  ['whole milk', 'processed cheese', 'curd'],
#  ['other vegetables',
#   'tropical fruit',
#   'root vegetables',
#   'fruit/vegetable juice'],
#  ['condensed milk',
#   'sausage',
#   'domestic eggs',
#   'whipped/sour cream',
#   'misc. beverages'],
#  ['processed cheese',
#   'condensed milk',
#   'rolls/buns',
#   'other vegetables',
#   'canned fish'],
#  ['pastry', 'whole milk'],
#  ['root vegetables',
#   'citrus fruit',
#   'root vegetables',
#   'bottled water',
#   'Instant food products',
#   'hard cheese',
#   'butter milk',
#   'mayonnaise'],
#  ['frozen meals',
#   'sausage',
#   'citrus fruit',
#   'canned beer',
#   'brown bread',
#   'fruit/vegetable juice',
#   'frozen vegetables',
#   'chocolate'],
#  ['whole milk', 'curd', 'other vegetables', 'butter'],
#  ['ham', 'sausage', 'UHT-milk', 'curd', 'other vegetables', 'bottled water'],
#  ['Instant food products', 'bottled beer', 'butter'],
#  ['chicken', 'onions'],
#  ['frankfurter', 'waffles', 'coffee', 'dishes', 'domestic eggs', 'oil'],
#  ['onions',
#   'whipped/sour cream',
#   'grapes',
#   'waffles',
#   'yogurt',
#   'spread cheese'],
#  ['citrus fruit', 'frozen meals'],
#  ['rolls/buns', 'domestic eggs', 'napkins'],
#  ['pet care', 'flour', 'coffee', 'napkins'],
#  ['other vegetables', 'bottled water'],
#  ['cling film/bags', 'napkins'],
#  ['UHT-milk', 'whole milk', 'canned beer'],
#  ['meat', 'curd'],
#  ['other vegetables', 'margarine'],
#  ['bottled water',
#   'tropical fruit',
#   'whole milk',
#   'whole milk',
#   'other vegetables',
#   'frozen vegetables'],
#  ['grapes', 'frozen vegetables', 'vinegar'],
#  ['sausage', 'whole milk'],
#  ['whole milk', 'root vegetables', 'whole milk', 'whole milk', 'rolls/buns'],
#  ['whole milk', 'pot plants'],
#  ['mustard', 'flour'],
#  ['citrus fruit', 'rolls/buns', 'pastry'],
#  ['whipped/sour cream', 'brown bread'],
#  ['frankfurter', 'berries'],
#  ['honey', 'yogurt', 'spices', 'chocolate'],
#  ['bottled water', 'root vegetables', 'bottled beer', 'pastry'],
#  ['other vegetables', 'fruit/vegetable juice'],
#  ['napkins', 'white bread'],
#  ['ham', 'other vegetables', 'pastry', 'rolls/buns', 'bottled water', 'soda'],
#  ['tropical fruit', 'dessert', 'frozen vegetables', 'margarine', 'rice'],
#  ['chicken', 'shopping bags', 'other vegetables', 'whole milk'],
#  ['other vegetables', 'red/blush wine', 'specialty chocolate', 'dog food'],
#  ['fruit/vegetable juice', 'white bread'],
#  ['bottled water', 'bottled water'],
#  ['sliced cheese', 'soda', 'oil', 'syrup'],
#  ['whole milk', 'citrus fruit'],
#  ['frankfurter',
#   'grapes',
#   'soda',
#   'salt',
#   'napkins',
#   'rolls/buns',
#   'soda',
#   'shopping bags'],
#  ['other vegetables',
#   'pip fruit',
#   'tropical fruit',
#   'domestic eggs',
#   'sweet spreads'],
#  ['white wine', 'rolls/buns'],
#  ['beef', 'whole milk', 'pip fruit', 'other vegetables'],
#  ['frankfurter',
#   'beef',
#   'soda',
#   'rolls/buns',
#   'berries',
#   'pastry',
#   'bottled water',
#   'ketchup',
#   'pastry',
#   'semi-finished bread'],
#  ['root vegetables', 'chewing gum', 'chocolate', 'bottled beer'],
#  ['soda', 'beef'],
#  ['bottled water', 'whole milk', 'domestic eggs', 'domestic eggs'],
#  ['curd', 'cat food'],
#  ['canned beer', 'frankfurter', 'shopping bags', 'hard cheese', 'butter'],
#  ['whole milk',
#   'herbs',
#   'bottled water',
#   'soda',
#   'whole milk',
#   'frozen vegetables'],
#  ['meat', 'other vegetables'],
#  ['tropical fruit', 'detergent', 'rolls/buns', 'coffee'],
#  ['tropical fruit', 'bottled water'],
#  ...]

# %%
supports = range(1, 21)  # Test supports from 1% to 20%
num_itemsets = []

for supp in supports:
    rules = get_fim(supp*-1, transactions)
    num_itemsets.append(len(rules))

plt.plot(supports, num_itemsets, marker='o')
plt.axhline(y = len(df_grouped)*0.2, color = 'r', label = '20% of transactions')
plt.xticks([x for x in range(21)])
plt.xlabel("Support Threshold (%)")
plt.ylabel("Number of Frequent Itemsets")
plt.title("Elbow Method for Choosing Support")
plt.legend()
plt.show()

# %%
plt.plot(supports, num_itemsets, marker='o')
plt.axhline(y = len(df_grouped)*0.2, color = 'r', label = '20% of transactions')
plt.xticks([x for x in range(21)])
plt.xlabel("Support Threshold (%)")
plt.ylabel("Number of Frequent Itemsets")
plt.ylim([0,20000])
plt.title("Elbow Method for Choosing Support")
plt.legend()
plt.show()

# %%
get_fim(-9, transactions)
# Out:
#                                       itemset  support_absolute  \
# 0                               (whole milk,)              2253
# 2                         (other vegetables,)              1771
# 6                               (rolls/buns,)              1595
# 13                                    (soda,)              1411
# 25                                  (yogurt,)              1258
# ...                                       ...               ...
# 1970        (soft cheese, whipped/sour cream)                 9
# 1966              (soft cheese, citrus fruit)                 9
# 1964            (soft cheese, tropical fruit)                 9
# 1961  (soft cheese, yogurt, other vegetables)                 9
# 2428                               (liqueur,)                 9
#
#       support_relative
# 0             0.194896
# 2             0.153201
# 6             0.137976
# 13            0.122059
# 25            0.108824
# ...                ...
# 1970          0.000779
# 1966          0.000779
# 1964          0.000779
# 1961          0.000779
# 2428          0.000779
#
# [2429 rows x 3 columns]

# %%
confidence = range(10, 81, 5)  # Test supports from 1% to 20%
num_itemsets = []

for conf in confidence:
    rules = get_sig(-4, conf, transactions)
    num_itemsets.append(len(rules))

plt.plot(confidence, num_itemsets, marker='o')
plt.xlabel("Confidence Threshold (%)")
plt.ylabel("Number of Significant Itemsets")
plt.title("Elbow Method for Choosing Confidence Threshold")
plt.show()

# %%
get_sig(-9, 30, transactions)
# Out:
#             consequent                             antecedent  \
# 24          whole milk                      (sausage, yogurt)
# 59          whole milk                   (pastry, rolls/buns)
# 58          whole milk             (pastry, other vegetables)
# 65          whole milk                       (pastry, yogurt)
# 120         whole milk                    (pip fruit, yogurt)
# ...                ...                                    ...
# 1116  other vegetables        (butter milk, soda, whole milk)
# 1117        rolls/buns        (butter milk, soda, whole milk)
# 1118              soda  (butter milk, rolls/buns, whole milk)
# 1120        rolls/buns      (butter milk, yogurt, whole milk)
# 2068  other vegetables                    (organic products,)
#
#       support_absolute  support_relative  confidence_pct
# 24                  42          0.003633        0.344262
# 59                  33          0.002855        0.343750
# 58                  31          0.002682        0.310000
# 65                  27          0.002336        0.333333
# 120                 26          0.002249        0.333333
# ...                ...               ...             ...
# 1116                 3          0.000260        0.300000
# 1117                 3          0.000260        0.300000
# 1118                 3          0.000260        0.300000
# 1120                 3          0.000260        0.300000
# 2068                 3          0.000260        0.300000
#
# [2069 rows x 5 columns]

# %% [markdown]
# # Spotify Dataset

# %% [markdown]
# ## Preliminaries

# %%
#path = r"C:\Users\bianc\Desktop\AssocRuleLearning\dataset.csv"
path = r"dataset.csv"
df = pd.read_csv(path, index_col=0)
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %%
df.dtypes
# Out:
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Dropping Null Values

# %%
df.isnull().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ### Removing Duplicates

# %%
print(df['track_id'].duplicated().sum())
# Out:
# 24259

# %%
df['track_id'].value_counts().head(10)
# Out:
# track_id
# 6S3JlDAGk3uu3NtZbPnuhS    9
# 2Ey6v4Sekh3Z0RUSISRosD    8
# 2kkvB3RNRzwjFdGhaUA0tz    8
# 08kTa3SL9sV6Iy8KLKtGql    7
# 4XYieGKSlJlHpzB3bl6WMP    7
# 5ZsAhuQ24mWHiduaxJqnhW    7
# 0YLSjVxSb5FT1Bo8Tnxr8j    7
# 4WJTKbNJQ41zXnb84jSWaj    7
# 2aaClnypAakdAmLw74JXxB    7
# 2vU6bm5hVF2idVknGzqyPL    7
# Name: count, dtype: int64

# %% [markdown]
# retain the most popular version of each song

# %%
df = df.sort_values(by='popularity', ascending=False).drop_duplicates(subset='track_id').reset_index(drop=True)
print(df['track_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Preprocessing Int Columns

# %%
int_cols = df.select_dtypes(include=['int64']).columns
int_cols
# Out:
# Index(['popularity', 'duration_ms', 'key', 'mode', 'time_signature'], dtype='object')

# %%
int_cols = ['popularity','duration_ms']
df[int_cols].hist(figsize=(16, 8),bins=50)
plt.show()

# %% [markdown]
# #### Binning

# %%
# range and stdev as the bin criteria → if data is more dispersed, assign more bins to capture data granularity
three_bin = []
five_bin = []

for x in int_cols:
    range = df[x].max() - df[x].min()
    std = df[x].std()
    if range < 3 * std:
        three_bin.append(x)
    else:
        five_bin.append(x)

print("Columns with 3 bins:", three_bin)
print("Columns with 5 bins:", five_bin)
# Out:
# Columns with 3 bins: []
# Columns with 5 bins: ['popularity', 'duration_ms']

# %%
labels_3 = ['Low', 'Medium', 'High']
labels_5 = ['Very Low', 'Low', 'Medium', 'High', 'Very High']

df_bins = df[['track_id']].copy()

for col in three_bin:
    df_bins[col + '_bin'] = pd.cut(df[col], bins=3, labels=labels_3)

for col in five_bin:
    df_bins[col + '_bin'] = pd.cut(df[col], bins=5, labels=labels_5)

df_bins_int = df_bins
df_bins
# Out:
#                      track_id popularity_bin duration_ms_bin
# 0      3nqQXoyQOWXiESFLlDF1hG      Very High        Very Low
# 1      2tTmW7RDtMQtBk7m2rYeSw      Very High        Very Low
# 2      5ww2BF9slyYgNOk37BlC4u      Very High        Very Low
# 3      4uUG5RXrOk84mYEfFvj3cK      Very High        Very Low
# 4      1IHWl5LamUGEuP4ozKQSXZ      Very High        Very Low
# ...                       ...            ...             ...
# 89735  4VnsZmAkvBEX5BWxMAWBBG       Very Low        Very Low
# 89736  4WCpgL2vHyx2vusJ5mbBnF       Very Low        Very Low
# 89737  5FImqqYMK6ZwLwClPDds8c       Very Low        Very Low
# 89738  4BsasVXlffiJ69bRrJXWZO       Very Low        Very Low
# 89739  4zKQYMQrd6QuyzoOCZmf6C       Very Low        Very Low
#
# [89740 rows x 3 columns]

# %%
binned_cols = [col for col in df_bins.columns if col.endswith('_bin')]

fig, axes = plt.subplots(1,2,figsize=(14, 10))
axes = axes.flatten()

for i, x in enumerate(binned_cols):
    value_counts = df_bins[x].value_counts().sort_index()
    bars = value_counts.plot(kind='bar', ax=axes[i])

    axes[i].set_title(f"Bar Chart of {x}")
    axes[i].set_xlabel(x)
    axes[i].set_ylabel("Count")


plt.tight_layout()
plt.show()

# %%
df_int_encoded = pd.get_dummies(df_bins[binned_cols])
df_int_encoded = pd.concat([df_bins[['track_id']], df_int_encoded], axis=1)
df_int_encoded
# Out:
#                      track_id  popularity_bin_Very Low  popularity_bin_Low  \
# 0      3nqQXoyQOWXiESFLlDF1hG                    False               False
# 1      2tTmW7RDtMQtBk7m2rYeSw                    False               False
# 2      5ww2BF9slyYgNOk37BlC4u                    False               False
# 3      4uUG5RXrOk84mYEfFvj3cK                    False               False
# 4      1IHWl5LamUGEuP4ozKQSXZ                    False               False
# ...                       ...                      ...                 ...
# 89735  4VnsZmAkvBEX5BWxMAWBBG                     True               False
# 89736  4WCpgL2vHyx2vusJ5mbBnF                     True               False
# 89737  5FImqqYMK6ZwLwClPDds8c                     True               False
# 89738  4BsasVXlffiJ69bRrJXWZO                     True               False
# 89739  4zKQYMQrd6QuyzoOCZmf6C                     True               False
#
#        popularity_bin_Medium  popularity_bin_High  popularity_bin_Very High  \
# 0                      False                False                      True
# 1                      False                False                      True
# 2                      False                False                      True
# 3                      False                False                      True
# 4                      False                False                      True
# ...                      ...                  ...                       ...
# 89735                  False                False                     False
# 89736                  False                False                     False
# 89737                  False                False                     False
# 89738                  False                False                     False
# 89739                  False                False                     False
#
#        duration_ms_bin_Very Low  duration_ms_bin_Low  duration_ms_bin_Medium  \
# 0                          True                False                   False
# 1                          True                False                   False
# 2                          True                False                   False
# 3                          True                False                   False
# 4                          True                False                   False
# ...                         ...                  ...                     ...
# 89735                      True                False                   False
# 89736                      True                False                   False
# 89737                      True                False                   False
# 89738                      True                False                   False
# 89739                      True                False                   False
#
#        duration_ms_bin_High  duration_ms_bin_Very High
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
# ...                     ...                        ...
# 89735                 False                      False
# 89736                 False                      False
# 89737                 False                      False
# 89738                 False                      False
# 89739                 False                      False
#
# [89740 rows x 11 columns]

# %% [markdown]
# ### Preprocessing Float Columns

# %%
float_cols = df.select_dtypes(include=['float64']).columns
df[float_cols].describe()
# Out:
#        danceability        energy      loudness   speechiness  acousticness  \
# count  89740.000000  89740.000000  89740.000000  89740.000000  89740.000000
# mean       0.562166      0.634458     -8.498994      0.087442      0.328285
# std        0.176692      0.256606      5.221518      0.113278      0.338321
# min        0.000000      0.000000    -49.531000      0.000000      0.000000
# 25%        0.450000      0.457000    -10.322250      0.036000      0.017100
# 50%        0.576000      0.676000     -7.185000      0.048900      0.188000
# 75%        0.692000      0.853000     -5.108000      0.085900      0.625000
# max        0.985000      1.000000      4.532000      0.965000      0.996000
#
#        instrumentalness      liveness       valence         tempo
# count      89740.000000  89740.000000  89740.000000  89740.000000
# mean           0.173415      0.216971      0.469474    122.058134
# std            0.323849      0.194885      0.262864     30.117651
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.098200      0.249000     99.262750
# 50%            0.000058      0.132000      0.457000    122.013000
# 75%            0.097625      0.279000      0.682000    140.077000
# max            1.000000      1.000000      0.995000    243.372000

# %%
df[float_cols].hist(figsize=(16, 8),bins=50)
plt.show()

# %% [markdown]
# #### Binning

# %%
# range and stdev as the bin criteria → if data is more dispersed, assign more bins to capture data granularity
three_bins = []
five_bins = []

for x in float_cols:
    range = df[x].max() - df[x].min()
    std = df[x].std()
    if x == 'speechiness':  # based on kaggle column description → 3 bins
        three_bins.append(x)
    elif range < 3 * std:
        three_bins.append(x)
    else:
        five_bins.append(x)

print("Columns with 3 bins:", three_bins)
print("Columns with 5 bins:", five_bins)
# Out:
# Columns with 3 bins: ['speechiness', 'acousticness']
# Columns with 5 bins: ['danceability', 'energy', 'loudness', 'instrumentalness', 'liveness', 'valence', 'tempo']

# %%
df_bins = df[['track_id']].copy()

for x in three_bins:
    df_bins[x + '_bin'] = pd.cut(df[x], bins=3, labels=labels_3)

for x in five_bins:
    df_bins[x + '_bin'] = pd.cut(df[x], bins=5, labels=labels_5)

df_bins_float = df_bins
df_bins
# Out:
#                      track_id speechiness_bin acousticness_bin  \
# 0      3nqQXoyQOWXiESFLlDF1hG             Low              Low
# 1      2tTmW7RDtMQtBk7m2rYeSw             Low              Low
# 2      5ww2BF9slyYgNOk37BlC4u             Low           Medium
# 3      4uUG5RXrOk84mYEfFvj3cK             Low              Low
# 4      1IHWl5LamUGEuP4ozKQSXZ             Low              Low
# ...                       ...             ...              ...
# 89735  4VnsZmAkvBEX5BWxMAWBBG             Low              Low
# 89736  4WCpgL2vHyx2vusJ5mbBnF             Low              Low
# 89737  5FImqqYMK6ZwLwClPDds8c             Low              Low
# 89738  4BsasVXlffiJ69bRrJXWZO             Low              Low
# 89739  4zKQYMQrd6QuyzoOCZmf6C             Low              Low
#
#       danceability_bin energy_bin loudness_bin instrumentalness_bin  \
# 0                 High     Medium         High             Very Low
# 1                 High       High    Very High             Very Low
# 2            Very High       High    Very High             Very Low
# 3               Medium  Very High    Very High             Very Low
# 4                 High       High    Very High             Very Low
# ...                ...        ...          ...                  ...
# 89735             High       High    Very High             Very Low
# 89736             High  Very High    Very High             Very Low
# 89737             High       High    Very High             Very Low
# 89738             High       High    Very High             Very Low
# 89739              Low       High         High                 High
#
#       liveness_bin valence_bin tempo_bin
# 0              Low         Low    Medium
# 1              Low      Medium    Medium
# 2              Low   Very High    Medium
# 3              Low         Low    Medium
# 4         Very Low    Very Low    Medium
# ...            ...         ...       ...
# 89735     Very Low        High    Medium
# 89736          Low      Medium    Medium
# 89737     Very Low        High    Medium
# 89738     Very Low        High    Medium
# 89739     Very Low    Very Low      High
#
# [89740 rows x 10 columns]

# %%
binned_cols = [col for col in df_bins.columns if col.endswith('_bin')]

fig, axes = plt.subplots(3, 3, figsize=(14, 10))
axes = axes.flatten()

for i, x in enumerate(binned_cols):
    value_counts = df_bins[x].value_counts().sort_index()
    bars = value_counts.plot(kind='bar', ax=axes[i])

    axes[i].set_title(f"Bar Chart of {x}")
    axes[i].set_xlabel(x)
    axes[i].set_ylabel("Count")


plt.tight_layout()
plt.show()

# %% [markdown]
# #### One hot encoding

# %%
# one hot encode the features
df_flt_encoded = pd.get_dummies(df_bins[binned_cols])
df_flt_encoded = pd.concat([df_bins[['track_id']], df_flt_encoded], axis=1)
df_flt_encoded
# Out:
#                      track_id  speechiness_bin_Low  speechiness_bin_Medium  \
# 0      3nqQXoyQOWXiESFLlDF1hG                 True                   False
# 1      2tTmW7RDtMQtBk7m2rYeSw                 True                   False
# 2      5ww2BF9slyYgNOk37BlC4u                 True                   False
# 3      4uUG5RXrOk84mYEfFvj3cK                 True                   False
# 4      1IHWl5LamUGEuP4ozKQSXZ                 True                   False
# ...                       ...                  ...                     ...
# 89735  4VnsZmAkvBEX5BWxMAWBBG                 True                   False
# 89736  4WCpgL2vHyx2vusJ5mbBnF                 True                   False
# 89737  5FImqqYMK6ZwLwClPDds8c                 True                   False
# 89738  4BsasVXlffiJ69bRrJXWZO                 True                   False
# 89739  4zKQYMQrd6QuyzoOCZmf6C                 True                   False
#
#        speechiness_bin_High  acousticness_bin_Low  acousticness_bin_Medium  \
# 0                     False                  True                    False
# 1                     False                  True                    False
# 2                     False                 False                     True
# 3                     False                  True                    False
# 4                     False                  True                    False
# ...                     ...                   ...                      ...
# 89735                 False                  True                    False
# 89736                 False                  True                    False
# 89737                 False                  True                    False
# 89738                 False                  True                    False
# 89739                 False                  True                    False
#
#        acousticness_bin_High  danceability_bin_Very Low  danceability_bin_Low  \
# 0                      False                      False                 False
# 1                      False                      False                 False
# 2                      False                      False                 False
# 3                      False                      False                 False
# 4                      False                      False                 False
# ...                      ...                        ...                   ...
# 89735                  False                      False                 False
# 89736                  False                      False                 False
# 89737                  False                      False                 False
# 89738                  False                      False                 False
# 89739                  False                      False                  True
#
#        danceability_bin_Medium  ...  valence_bin_Very Low  valence_bin_Low  \
# 0                        False  ...                 False             True
# 1                        False  ...                 False            False
# 2                        False  ...                 False            False
# 3                         True  ...                 False             True
# 4                        False  ...                  True            False
# ...                        ...  ...                   ...              ...
# 89735                    False  ...                 False            False
# 89736                    False  ...                 False            False
# 89737                    False  ...                 False            False
# 89738                    False  ...                 False            False
# 89739                    False  ...                  True            False
#
#        valence_bin_Medium  valence_bin_High  valence_bin_Very High  \
# 0                   False             False                  False
# 1                    True             False                  False
# 2                   False             False                   True
# 3                   False             False                  False
# 4                   False             False                  False
# ...                   ...               ...                    ...
# 89735               False              True                  False
# 89736                True             False                  False
# 89737               False              True                  False
# 89738               False              True                  False
# 89739               False             False                  False
#
#        tempo_bin_Very Low  tempo_bin_Low  tempo_bin_Medium  tempo_bin_High  \
# 0                   False          False              True           False
# 1                   False          False              True           False
# 2                   False          False              True           False
# 3                   False          False              True           False
# 4                   False          False              True           False
# ...                   ...            ...               ...             ...
# 89735               False          False              True           False
# 89736               False          False              True           False
# 89737               False          False              True           False
# 89738               False          False              True           False
# 89739               False          False             False            True
#
#        tempo_bin_Very High
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 89735                False
# 89736                False
# 89737                False
# 89738                False
# 89739                False
#
# [89740 rows x 42 columns]

# %% [markdown]
# ### Merge

# %%
# merge binned int and float vars into one dataframe
df_merged = df_int_encoded.merge(df_flt_encoded, on='track_id', how='inner')
df_merged
# Out:
#                      track_id  popularity_bin_Very Low  popularity_bin_Low  \
# 0      3nqQXoyQOWXiESFLlDF1hG                    False               False
# 1      2tTmW7RDtMQtBk7m2rYeSw                    False               False
# 2      5ww2BF9slyYgNOk37BlC4u                    False               False
# 3      4uUG5RXrOk84mYEfFvj3cK                    False               False
# 4      1IHWl5LamUGEuP4ozKQSXZ                    False               False
# ...                       ...                      ...                 ...
# 89735  4VnsZmAkvBEX5BWxMAWBBG                     True               False
# 89736  4WCpgL2vHyx2vusJ5mbBnF                     True               False
# 89737  5FImqqYMK6ZwLwClPDds8c                     True               False
# 89738  4BsasVXlffiJ69bRrJXWZO                     True               False
# 89739  4zKQYMQrd6QuyzoOCZmf6C                     True               False
#
#        popularity_bin_Medium  popularity_bin_High  popularity_bin_Very High  \
# 0                      False                False                      True
# 1                      False                False                      True
# 2                      False                False                      True
# 3                      False                False                      True
# 4                      False                False                      True
# ...                      ...                  ...                       ...
# 89735                  False                False                     False
# 89736                  False                False                     False
# 89737                  False                False                     False
# 89738                  False                False                     False
# 89739                  False                False                     False
#
#        duration_ms_bin_Very Low  duration_ms_bin_Low  duration_ms_bin_Medium  \
# 0                          True                False                   False
# 1                          True                False                   False
# 2                          True                False                   False
# 3                          True                False                   False
# 4                          True                False                   False
# ...                         ...                  ...                     ...
# 89735                      True                False                   False
# 89736                      True                False                   False
# 89737                      True                False                   False
# 89738                      True                False                   False
# 89739                      True                False                   False
#
#        duration_ms_bin_High  ...  valence_bin_Very Low  valence_bin_Low  \
# 0                     False  ...                 False             True
# 1                     False  ...                 False            False
# 2                     False  ...                 False            False
# 3                     False  ...                 False             True
# 4                     False  ...                  True            False
# ...                     ...  ...                   ...              ...
# 89735                 False  ...                 False            False
# 89736                 False  ...                 False            False
# 89737                 False  ...                 False            False
# 89738                 False  ...                 False            False
# 89739                 False  ...                  True            False
#
#        valence_bin_Medium  valence_bin_High  valence_bin_Very High  \
# 0                   False             False                  False
# 1                    True             False                  False
# 2                   False             False                   True
# 3                   False             False                  False
# 4                   False             False                  False
# ...                   ...               ...                    ...
# 89735               False              True                  False
# 89736                True             False                  False
# 89737               False              True                  False
# 89738               False              True                  False
# 89739               False             False                  False
#
#        tempo_bin_Very Low  tempo_bin_Low  tempo_bin_Medium  tempo_bin_High  \
# 0                   False          False              True           False
# 1                   False          False              True           False
# 2                   False          False              True           False
# 3                   False          False              True           False
# 4                   False          False              True           False
# ...                   ...            ...               ...             ...
# 89735               False          False              True           False
# 89736               False          False              True           False
# 89737               False          False              True           False
# 89738               False          False              True           False
# 89739               False          False             False            True
#
#        tempo_bin_Very High
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 89735                False
# 89736                False
# 89737                False
# 89738                False
# 89739                False
#
# [89740 rows x 52 columns]

# %%
# add 'explicit' column
df_merged = df_merged.merge(df[['track_id', 'explicit']], on='track_id', how='left')
df_merged
# Out:
#                      track_id  popularity_bin_Very Low  popularity_bin_Low  \
# 0      3nqQXoyQOWXiESFLlDF1hG                    False               False
# 1      2tTmW7RDtMQtBk7m2rYeSw                    False               False
# 2      5ww2BF9slyYgNOk37BlC4u                    False               False
# 3      4uUG5RXrOk84mYEfFvj3cK                    False               False
# 4      1IHWl5LamUGEuP4ozKQSXZ                    False               False
# ...                       ...                      ...                 ...
# 89735  4VnsZmAkvBEX5BWxMAWBBG                     True               False
# 89736  4WCpgL2vHyx2vusJ5mbBnF                     True               False
# 89737  5FImqqYMK6ZwLwClPDds8c                     True               False
# 89738  4BsasVXlffiJ69bRrJXWZO                     True               False
# 89739  4zKQYMQrd6QuyzoOCZmf6C                     True               False
#
#        popularity_bin_Medium  popularity_bin_High  popularity_bin_Very High  \
# 0                      False                False                      True
# 1                      False                False                      True
# 2                      False                False                      True
# 3                      False                False                      True
# 4                      False                False                      True
# ...                      ...                  ...                       ...
# 89735                  False                False                     False
# 89736                  False                False                     False
# 89737                  False                False                     False
# 89738                  False                False                     False
# 89739                  False                False                     False
#
#        duration_ms_bin_Very Low  duration_ms_bin_Low  duration_ms_bin_Medium  \
# 0                          True                False                   False
# 1                          True                False                   False
# 2                          True                False                   False
# 3                          True                False                   False
# 4                          True                False                   False
# ...                         ...                  ...                     ...
# 89735                      True                False                   False
# 89736                      True                False                   False
# 89737                      True                False                   False
# 89738                      True                False                   False
# 89739                      True                False                   False
#
#        duration_ms_bin_High  ...  valence_bin_Low  valence_bin_Medium  \
# 0                     False  ...             True               False
# 1                     False  ...            False                True
# 2                     False  ...            False               False
# 3                     False  ...             True               False
# 4                     False  ...            False               False
# ...                     ...  ...              ...                 ...
# 89735                 False  ...            False               False
# 89736                 False  ...            False                True
# 89737                 False  ...            False               False
# 89738                 False  ...            False               False
# 89739                 False  ...            False               False
#
#        valence_bin_High  valence_bin_Very High  tempo_bin_Very Low  \
# 0                 False                  False               False
# 1                 False                  False               False
# 2                 False                   True               False
# 3                 False                  False               False
# 4                 False                  False               False
# ...                 ...                    ...                 ...
# 89735              True                  False               False
# 89736             False                  False               False
# 89737              True                  False               False
# 89738              True                  False               False
# 89739             False                  False               False
#
#        tempo_bin_Low  tempo_bin_Medium  tempo_bin_High  tempo_bin_Very High  \
# 0              False              True           False                False
# 1              False              True           False                False
# 2              False              True           False                False
# 3              False              True           False                False
# 4              False              True           False                False
# ...              ...               ...             ...                  ...
# 89735          False              True           False                False
# 89736          False              True           False                False
# 89737          False              True           False                False
# 89738          False              True           False                False
# 89739          False             False            True                False
#
#        explicit
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
# ...         ...
# 89735     False
# 89736     False
# 89737     False
# 89738     False
# 89739     False
#
# [89740 rows x 53 columns]

# %%
df_merged2 = df_merged.drop(columns=['track_id'])

transactions = df_merged2.apply(lambda row: list(df_merged2.columns[row.values]), axis=1).tolist()

# %% [markdown]
# ## Association Rule Learning

# %% [markdown]
# ### Frequent Itemset Mining

# %%
# calculates the frequent itemset using fpgrowth algorithm
def get_fim(supp, transactions):
    result = fpgrowth(transactions, supp=supp, report='as')
    colnames = ['itemset'] + ['support_absolute', 'support_relative']
    df_result = pd.DataFrame(result, columns=colnames)
    df_result = df_result.sort_values('support_absolute', ascending=False)
    return df_result

# %% [markdown]
# Checking for ideal support threshold

# %%
del(range)

# %%
supports = range(100, 1501, 50)  # Test supports from 1% to 20%
num_itemsets = []

for supp in supports:
    rules = get_fim(supp*-1, transactions)
    num_itemsets.append(len(rules))

plt.plot(supports, num_itemsets, marker='o')
plt.axhline(y = len(df_merged)*0.5, color = 'r', label = '50% of transactions')
plt.xticks([x for x in range(100, 1501, 50)], rotation=90)
plt.xlabel("Support Threshold (%)")
plt.ylabel("Number of Frequent Itemsets")
plt.title("Elbow Method for Choosing Support")
plt.legend()
plt.show()

# %% [markdown]
# Zoom in to the Plot

# %%
plt.plot(supports, num_itemsets, marker='o')
plt.axhline(y = len(df_merged)*0.5, color = 'r', label = '50% of transactions')
plt.xticks([x for x in range(100, 1501, 50)], rotation=90)
plt.xlabel("Support Threshold (%)")
plt.ylabel("Number of Frequent Itemsets")
plt.ylim([0,200_000])
plt.title("Elbow Method for Choosing Support")
plt.legend()
plt.show()

# %% [markdown]
# Since the "elbow" in the graph is not very observable (gradual change in slope), we chose the support value closest to 50% of the transactions (nearest point below the horizontal red line). <br/>
#
# ***Support Threshold is set to 750.***

# %% [markdown]
# ### Frequent Itemsets

# %%
get_fim(-750, transactions)
# Out:
#                                                 itemset  support_absolute  \
# 0                           (duration_ms_bin_Very Low,)             89646
# 2                                (speechiness_bin_Low,)             86350
# 1       (speechiness_bin_Low, duration_ms_bin_Very Low)             86262
# 6                      (instrumentalness_bin_Very Low,)             69480
# 3     (instrumentalness_bin_Very Low, duration_ms_bi...             69433
# ...                                                 ...               ...
# 3566  (liveness_bin_Medium, popularity_bin_Low, loud...               751
# 4026  (speechiness_bin_High, acousticness_bin_High, ...               751
# 4027  (speechiness_bin_High, acousticness_bin_High, ...               751
# 2752  (energy_bin_Low, danceability_bin_Low, popular...               751
# 3913            (speechiness_bin_Medium, tempo_bin_Low)               750
#
#       support_relative
# 0             0.998953
# 2             0.962224
# 1             0.961244
# 6             0.774237
# 3             0.773713
# ...                ...
# 3566          0.008369
# 4026          0.008369
# 4027          0.008369
# 2752          0.008369
# 3913          0.008357
#
# [4034 rows x 3 columns]

# %%
# calculates the frequent itemset using fpgrowth algorithm
def get_sig(supp, conf, transactions):
    result = arules(transactions, supp=supp, conf=conf, zmax=3, report='asc')
    colnames = ['consequent', 'antecedent'] + ['support_absolute', 'support_relative', 'confidence_pct']
    df_result = pd.DataFrame(result, columns=colnames)
    df_result = df_result.sort_values('support_absolute', ascending=False)
    return df_result

# %%
confidence = range(10, 101, 5)  # Test supports from 1% to 20%
num_itemsets = []

for conf in confidence:
    rules = get_sig(-750, conf, transactions)
    num_itemsets.append(len(rules))

plt.plot(confidence, num_itemsets, marker='o')
plt.xlabel("Confidence Threshold (%)")
plt.ylabel("Number of Significant Itemsets")
plt.title("Elbow Method for Choosing Confidence Threshold")
plt.show()

# %% [markdown]
# Since the "elbow" in the graph is not very observable (gradual change in slope), we chose the confidence threshold value closest to 50% of the transactions (nearest point below the horizontal red line). <br/>
#
# ***Support Threshold is set to 750.***

# %%
# focus on those where popularity appears in the consequent

rules = get_sig(-14, 45, transactions)
rules_filtered = rules[rules["consequent"].astype(str).str.contains("popularity", na=False)]
rules_filtered
# Out:
#                       consequent  \
# 957727   popularity_bin_Very Low
# 957670   popularity_bin_Very Low
# 957677   popularity_bin_Very Low
# 957674   popularity_bin_Very Low
# 957667   popularity_bin_Very Low
# ...                          ...
# 3099815       popularity_bin_Low
# 3701424  popularity_bin_Very Low
# 3701425  popularity_bin_Very Low
# 3701426  popularity_bin_Very Low
# 3701427  popularity_bin_Very Low
#
#                                                 antecedent  support_absolute  \
# 957727   (instrumentalness_bin_Very High, tempo_bin_Med...              2921
# 957670   (instrumentalness_bin_Very High, tempo_bin_Med...              2913
# 957677   (instrumentalness_bin_Very High, tempo_bin_Med...              2902
# 957674   (instrumentalness_bin_Very High, tempo_bin_Med...              2894
# 957667   (instrumentalness_bin_Very High, acousticness_...              2864
# ...                                                    ...               ...
# 3099815  (liveness_bin_High, loudness_bin_Medium, energ...                 7
# 3701424  (instrumentalness_bin_Low, energy_bin_Low, aco...                 7
# 3701425  (instrumentalness_bin_Low, energy_bin_Low, aco...                 7
# 3701426  (instrumentalness_bin_Low, energy_bin_Low, aco...                 7
# 3701427  (instrumentalness_bin_Low, energy_bin_Low, aco...                 7
#
#          support_relative  confidence_pct
# 957727           0.032550        0.453853
# 957670           0.032460        0.453244
# 957677           0.032338        0.453296
# 957674           0.032249        0.452683
# 957667           0.031914        0.509156
# ...                   ...             ...
# 3099815          0.000078        0.500000
# 3701424          0.000078        0.466667
# 3701425          0.000078        0.466667
# 3701426          0.000078        0.466667
# 3701427          0.000078        0.466667
#
# [169488 rows x 5 columns]

# %%
def get_antecedents(id, rules_df):

    antecedents_dict = {}

    for id in id:
          antecedents_dict[id] = rules_df.loc[id]["antecedent"]


    return antecedents_dict

id_list = [957727, 957670, 957677, 957674]
antecedents = get_antecedents(id_list, rules_filtered)

for id, antecedent in antecedents.items():
    print(f"Index {id}: {antecedent}")
# Out:
# Index 957727: ('instrumentalness_bin_Very High', 'tempo_bin_Medium')
# Index 957670: ('instrumentalness_bin_Very High', 'tempo_bin_Medium', 'duration_ms_bin_Very Low')
# Index 957677: ('instrumentalness_bin_Very High', 'tempo_bin_Medium', 'speechiness_bin_Low')
# Index 957674: ('instrumentalness_bin_Very High', 'tempo_bin_Medium', 'speechiness_bin_Low', 'duration_ms_bin_Very Low')

# %% [markdown]
# observations:
#
# among the top 4 rules, among which all had a consequent of very low popularity, very high instrumentalness and medium tempo appeared as an antecedent for all
#
# additional items that appeared was very low duration and low speechiness

# %%
df_combined = pd.merge(df_bins_int[['track_id', 'popularity_bin']], df_bins_float[['track_id', 'tempo_bin', 'instrumentalness_bin']], on='track_id', how='inner')

df_combined = pd.merge(df_combined, df[['track_id','track_genre']], on='track_id', how='inner')

df_check = df_combined[(df_combined["instrumentalness_bin"] == 'Very High') & (df_combined["tempo_bin"] == 'Medium')]
print(df_check["popularity_bin"].value_counts())
# Out:
# popularity_bin
# Very Low     2921
# Medium       1704
# Low          1646
# High          163
# Very High       2
# Name: count, dtype: int64

# %%
df_check = df_combined[(df_combined["instrumentalness_bin"] == 'Very High') & (df_combined["tempo_bin"] == 'Medium') & (df_combined["popularity_bin"] == 'Very Low')]
print(df_check["track_genre"].value_counts().head(5))
# Out:
# track_genre
# piano                23
# ambient              17
# sleep                11
# chill                10
# progressive-house     9
# Name: count, dtype: int64

# %%
df_check = df_combined[(df_combined["instrumentalness_bin"] == 'Very High') & (df_combined["tempo_bin"] == 'Medium') & ((df_combined["popularity_bin"] == 'High') | (df_combined["popularity_bin"] == 'Very High'))]
print(df_check["track_genre"].value_counts().head(5))
# Out:
# track_genre
# piano                23
# ambient              17
# sleep                11
# chill                10
# progressive-house     9
# Name: count, dtype: int64

# %% [markdown]
# **Spotify Dataset** (Total of 55 pts.)
#
# 1. Find another dataset that can be turned into an association rule learning problem. Ideally, more than 1000 transactions/records. This does not have to be grocery-related. (20 pts)
# 2. Similar to the grocery dataset, calculate the association rules and find the `significant/interesting` items. (10 pts)
#
# 3. What would you recommend given the association rules? (20 pts)
#   - Based on our analysis, songs that have very high instrumentalness and medium tempo often have lower popularity. This does not mean, however, that these songs cannot get popular. There are songs containing these characteristics that have a very high popularity status. These characteristics may be more common in niche genres that dont often reach the same mainstream success as other songs. Looking at the genres of songs with very high instrumentalness, medium tempo, and very low popularity, most fall under the general category of underground EDM music, extreme metal/punk, and regional music. At the point of view of someone in the music industry, analysis of audience expectations and music trends may help influence the way music is produced whether the goal is for an artist to reach mainstream or reach stronger engagement with more niche audiences.
#
#
# 4. Any other learnings? (5 pts)
#   - A lot of preprocessing may be needed depending on the original set of data to transform it into a form that can be used for association rule learning.
#   - The context in which association rule learning is used is very important. Unlike the groceries dataset wherein the goal was more clearly defined, the spotify dataset, having a lot of features, was more open ended. It might not have been needed to include everything in the association rule learning section as it would depend on the goal of the analysis. Using only the relevant features to the research goal may also improve the effectiveness of association rule learning.
#   - Correlation does not imply causality. Just like in the spotify dataset, it doesn't mean that very high instrumentalness and medium tempo in a song causes very low popularity. Extra analysis on the results may be done to extract useful insights

# %% [markdown]
# ## Writeup/Analysis
#
# Refer to the **Requirements section** for the guide questions.

# %% [markdown]
# ## References
#
# - sir jude
# -

# %% [markdown]
# ## End
# <sup>made by **Jude Michael Teves**</sup> <br>
# <sup>for comments, corrections, suggestions, please email:</sup><sup> <href>judemichaelteves@gmail.com</href> or <href>jude.teves@dlsu.edu.ph</href></sup><br>
